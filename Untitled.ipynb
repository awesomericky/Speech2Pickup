# %%
import numpy as np
from scipy.stats import multivariate_normal as mulnorm
import matplotlib.pyplot as plt

x = np.array(range(1024))
y = np.array(range(1280))
xx, yy = np.meshgrid(x, y)
xxyy = np.c_[xx.T.ravel(), yy.T.ravel()]

tmp_cov = [[1000, 0], [0, 1000]]
mvn = mulnorm([297, 239], tmp_cov)

tmp_heatmap = mvn.pdf(xxyy)
tmp_heatmap = tmp_heatmap / np.max(tmp_heatmap)
tmp_heatmap = tmp_heatmap.reshape((len(x), len(y)))
plt.imshow(tmp_heatmap, cmap='jet')

# %%
import numpy as np
import matplotlib.pyplot as plt

tmp_heatmap = np.load('./data/dataset2/heatmap/train/0096_0786_0520_0115_0105.npz')['heatmap']
plt.imshow(tmp_heatmap, cmap='jet')

# %%
from skimage import io

img = io.imread('./data/dataset2/image_file/96.png')
plt.imshow(img)

# %%
from skimage.transform import resize
from skimage import io
tmp_img = resize(img, [256, 256], preserve_range=True)
tmp_img = tmp_img / 255.0
plt.imshow(tmp_img)

# %%
from skimage.transform import resize

tmp_heatmap = resize(tmp_heatmap, [250, 250], preserve_range=True)
plt.imshow(tmp_heatmap, cmap='jet')
