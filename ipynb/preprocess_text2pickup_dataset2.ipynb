# %%
from preprocess_dataset2 import preprocess_text2pickup

preprocess_text2pickup(start_point=0, only_test_data=False)
# Out:
# Start loading Google Word2Vec data
# Finished loading Google Word2Vec data
# Total data number: 90759
# Total train data number: 89861
# Total test data number: 898
# Now processing Train data ..
# Processing 1/1160
# Processing 2/1160
# Processing 3/1160
# Processing 4/1160
# Processing 5/1160
# Processing 6/1160
# Processing 7/1160
# Processing 8/1160
# Processing 9/1160
# Processing 10/1160
# Processing 11/1160
# Processing 12/1160
# Processing 13/1160
# Processing 14/1160
# Processing 15/1160
# Processing 16/1160
# Processing 17/1160
# Processing 18/1160
# Processing 19/1160
# Processing 20/1160
# Processing 21/1160
# Processing 22/1160
# Processing 23/1160
# Processing 24/1160
# Processing 25/1160
# Processing 26/1160
# Processing 27/1160
# Processing 28/1160
# Processing 29/1160
# Processing 30/1160
# Processing 31/1160
# Processing 32/1160
# Processing 33/1160
# Processing 34/1160
# Processing 35/1160
# Processing 36/1160
# Processing 37/1160
# Processing 38/1160
# ...
