# %% [markdown]
# ### Import dependencies

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
% pip install wandb
# Out:
# Collecting wandb
#   Downloading https://files.pythonhosted.org/packages/ca/5e/9df94df3bfee51b92b54a5e6fa277d6e1fcdf1f27b1872214b98f55ec0f7/wandb-0.10.12-py2.py3-none-any.whl (1.8MB)
#      |████████████████████████████████| 1.8MB 14.0MB/s
# Collecting configparser>=3.8.1
#   Downloading https://files.pythonhosted.org/packages/08/b2/ef713e0e67f6e7ec7d59aea3ee78d05b39c15930057e724cc6d362a8c3bb/configparser-5.0.1-py3-none-any.whl
# Collecting subprocess32>=3.5.3
#   Downloading https://files.pythonhosted.org/packages/32/c8/564be4d12629b912ea431f1a50eb8b3b9d00f1a0b1ceff17f266be190007/subprocess32-3.5.4.tar.gz (97kB)
#      |████████████████████████████████| 102kB 13.8MB/s
# Collecting sentry-sdk>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/b1/5c/018bf9a5c24343a664deaea70e61f33f53bb1bd3caf193110f827bfd07e2/sentry_sdk-0.19.5-py2.py3-none-any.whl (128kB)
#      |████████████████████████████████| 133kB 43.2MB/s
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from wandb) (2.8.1)
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (7.1.2)
# Collecting docker-pycreds>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/f5/e8/f6bd1eee09314e7e6dee49cbe2c5e22314ccdb38db16c9fc72d2fa80d054/docker_pycreds-0.4.0-py2.py3-none-any.whl
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (3.12.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from wandb) (3.13)
# Collecting shortuuid>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/25/a6/2ecc1daa6a304e7f1b216f0896b26156b78e7c38e1211e9b798b4716c53d/shortuuid-1.0.1-py3-none-any.whl
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (2.3)
# Collecting GitPython>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/24/d1/a7f8fe3df258549b303415157328bfcc63e9b11d06a7ad7a3327f3d32606/GitPython-3.1.11-py3-none-any.whl (159kB)
#      |████████████████████████████████| 163kB 69.7MB/s
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (5.4.8)
# Collecting watchdog>=0.8.3
#   Downloading https://files.pythonhosted.org/packages/83/d9/3d1f46b428fd7b646725896b58d2eddb84f79fd76912773e6193cf74263d/watchdog-1.0.2-py3-none-manylinux2014_x86_64.whl (72kB)
#      |████████████████████████████████| 81kB 11.3MB/s
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: urllib3>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from sentry-sdk>=0.4.0->wandb) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from sentry-sdk>=0.4.0->wandb) (2020.12.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.12.0->wandb) (51.0.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/48/11/d1800bca0a3bae820b84b7d813ad1eff15a48a64caea9c823fc8c1b119e8/gitdb-4.0.5-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 9.6MB/s
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Collecting smmap<4,>=3.0.1
#   Downloading https://files.pythonhosted.org/packages/b0/9a/4d409a6234eb940e6a78dfdfc66156e7522262f5f2fecca07dc55915952d/smmap-3.0.4-py2.py3-none-any.whl
# Building wheels for collected packages: subprocess32
#   Building wheel for subprocess32 (setup.py) ... done
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-cp36-none-any.whl size=6490 sha256=562bc114e2f8e86136dd89f2a810e376eb49e7d955d71c8b5c292d708de527d0
#   Stored in directory: /root/.cache/pip/wheels/68/39/1a/5e402bdfdf004af1786c8b853fd92f8c4a04f22aad179654d1
# Successfully built subprocess32
# Installing collected packages: configparser, subprocess32, sentry-sdk, docker-pycreds, shortuuid, smmap, gitdb, GitPython, watchdog, wandb
# Successfully installed GitPython-3.1.11 configparser-5.0.1 docker-pycreds-0.4.0 gitdb-4.0.5 sentry-sdk-0.19.5 shortuuid-1.0.1 smmap-3.0.4 subprocess32-3.5.4 wandb-0.10.12 watchdog-1.0.2

# %%
import numpy as np
import tensorflow as tf
from skimage.transform import resize
import utils
from code_HGN_text2pickup_test import define_model, session_run
from os.path import isfile, exists

print('Load needed things!')
# Out:
# Load needed things!

# %% [markdown]
# ### Load w2v model : the pretrained model should be downloaded in your folder
#
# #### If not, check https://github.com/mmihaltz/word2vec-GoogleNews-vectors

# %%
w2v_path = '/content/drive/MyDrive/Speech2Pickup/GoogleNews-vectors-negative300.bin'
w2v_model = utils.load_w2v(w2v_path)
# Out:
# Start loading Google Word2Vec data
# Finished loading Google Word2Vec data

# %% [markdown]
# ### Load preprocessed data

# %%
relative_data_directory_path = '/content/drive/MyDrive/Speech2Pickup/data_text2pickup/preprocessed4HGN_text2pickup.npz'

data = np.load(relative_data_directory_path)

img_idx = data['arr_0']
seq_len = data['arr_1']
text_inputs = data['arr_2']
pos_outputs = data['arr_3']

dim_sentence = text_inputs.shape[1]
max_step_sentence = text_inputs.shape[2]
num_data = img_idx.shape[0]

# %% [markdown]
# ### Define Model : Run this cell only once per one kernel

# %%
result_heatmap, ph_image, ph_sen, ph_sen_len, ph_dropout= define_model(dim_sentence, 
                                                                       max_step_sentence, 
                                                                       num_hg_Depth = 4,
                                                                       dim_hg_feat = 256,
                                                                       dim_rnn_cell = 256)
# Out:
# WARNING:tensorflow:From /content/code_HGN_text2pickup_test.py:9: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/hourglass_with_rnn.py:121: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/hourglass_with_rnn.py:136: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /content/hourglass_with_rnn.py:137: The name tf.nn.rnn_cell.DropoutWrapper is deprecated. Please use tf.compat.v1.nn.rnn_cell.DropoutWrapper instead.
#
# WARNING:tensorflow:From /content/hourglass_with_rnn.py:138: static_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell, unroll=True)`, which is equivalent to this API
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/rnn_cell_impl.py:735: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/rnn_cell_impl.py:739: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/hourglass_with_rnn.py:81: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/hourglass_with_rnn.py:82: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From /content/hourglass_with_rnn.py:84: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# WARNING:tensorflow:From /content/hourglass_with_rnn.py:90: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# WARNING:tensorflow:From /content/hourglass_with_rnn.py:48: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /content/hourglass_with_rnn.py:51: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/hourglass_with_rnn.py:51: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/hourglass_with_rnn.py:57: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.

# %% [markdown]
# ### Get test image index. Refer the printed result when you check the result from the test data

# %%
idx_test, idx_train = utils.get_test_idx(img_idx, num_data)
# Out:
# Test image index : [154  47  59  31 419 446 217  63 152 236 289 229 434  67  45 316 352 135
#  285  77 318  41 142]

# %% [markdown]
# ### Choose the image index for the test

# %%
test_img_idx = 77
img_path = '/content/drive/MyDrive/Speech2Pickup/train_img'
curr_test_img = utils.load_test_img(img_path, test_img_idx, img_resize=256, plot_flag = 1)

# %% [markdown]
# ### Set test input script and Run the Result

# %%
curr_test_input = "pick up the left block the green one"
curr_embed_input, curr_seq_len = utils.load_test_script(curr_test_input, w2v_model, 
                                                        dim_sentence, max_step_sentence)    
mean_of_esti, uncertainty = session_run(result_heatmap, ph_image, ph_sen, 
                                         ph_sen_len, ph_dropout,
                                         restore_path = '/content/drive/MyDrive/Speech2Pickup/Text2Pickup_model/model.ckpt',
                                         curr_embed_input = curr_embed_input,
                                         curr_seq_len = curr_seq_len,
                                         curr_test_img = curr_test_img,
                                         dropout_rate=0.1)
# Out:
# Ready the test input script
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Speech2Pickup/Text2Pickup_model/model.ckpt

# %% [markdown]
# ### See the Result

# %%
utils.plot_HGN_result(curr_test_input, curr_test_img, mean_of_esti, uncertainty, save_state=False, save_path='')

# %% [markdown]
# ### Evaluate 'Text2Pickup' model : Model should be first defined

# %%
# Restore model

restore_path = '/content/drive/MyDrive/Speech2Pickup/Text2Pickup_model/model.ckpt'
init = tf.global_variables_initializer()
saver = tf.train.Saver()

config = tf.ConfigProto()
config.allow_soft_placement = True
config.gpu_options.allow_growth = True

T = 100

sess = tf.Session(config=config)
sess.run(init)
saver.restore(sess, restore_path)
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Speech2Pickup/Text2Pickup_model/model.ckpt

# %%
# Evaluate model

import time

img_path = '/content/drive/MyDrive/Speech2Pickup/train_img'
dropout_rate = 0.1
num_test = len(idx_test)
num_correct = 0
correct_limit = 20 # 20 pixel (if the image size is 256x256)
error_idx = []
error = []

taken_times = []

for idx in idx_test:
    test_img_idx = img_idx[idx, :]
    curr_test_img = utils.load_test_img(img_path, test_img_idx, img_resize=256, plot_flag = 0)
    curr_embed_input = text_inputs[idx, :]
    curr_seq_len = seq_len[idx, :]
    curr_pos_outputs = pos_outputs[idx, :]

    start = time.time()
    
    test_feed_dict = {ph_sen: np.tile(curr_embed_input, (T, 1, 1)), 
                      ph_sen_len: np.tile(curr_seq_len, (T, 1)),
                      ph_image: np.tile(curr_test_img, (T, 1, 1, 1)),
                      ph_dropout: dropout_rate}
    test_heatmap = sess.run(result_heatmap, feed_dict=test_feed_dict)

    test_heatmap = np.squeeze(test_heatmap)
    mean_of_esti = np.mean(test_heatmap, axis=0)
    
    mean_of_esti = resize(mean_of_esti, [256, 256], preserve_range=True)

    end = time.time()

    pose_esti = np.unravel_index(np.argmax(mean_of_esti), mean_of_esti.shape)
    pose_esti = np.flip(pose_esti)
    
    distance = np.sqrt(np.sum((pose_esti - curr_pos_outputs)**2))
    if distance < correct_limit:
        num_correct += 1
    else:
        error_idx.append(idx)
        error.append(distance)

    taken_time = end - start
    taken_times.append(taken_time)

accuracy = (num_correct/num_test)*100
print('Text2Pickup accuracy: {}%'.format(accuracy))
# Out:
# Text2Pickup accuracy: 98.96421845574388%

# %%
taken_times_re = []

for i in taken_times:
    taken_times_re.append(i)
    taken_times_re.append(i)

# %%
# Plot error distance

import matplotlib.pyplot as plt

plt.plot(error)

# %%
# Plot one example of error case (maximum error)

idx = error_idx[np.argmax(error)]
test_img_idx = img_idx[idx, :]
curr_test_img = utils.load_test_img(img_path, test_img_idx, img_resize=256, plot_flag = 0)
curr_embed_input = text_inputs[idx, :]
curr_seq_len = seq_len[idx, :]
curr_pos_outputs = pos_outputs[idx, :]
curr_sentence = ''

test_feed_dict = {ph_sen: np.tile(curr_embed_input, (T, 1, 1)), 
                  ph_sen_len: np.tile(curr_seq_len, (T, 1)),
                  ph_image: np.tile(curr_test_img, (T, 1, 1, 1)),
                  ph_dropout: dropout_rate}
test_heatmap = sess.run(result_heatmap, feed_dict=test_feed_dict)

test_heatmap = np.squeeze(test_heatmap)
mean_of_esti = np.mean(test_heatmap, axis=0)
mean_of_squared_esti = np.mean(test_heatmap**2, axis=0)
squared_mean_of_esti = mean_of_esti ** 2
uncertainty = np.sqrt(mean_of_squared_esti - squared_mean_of_esti)
utils.plot_HGN_result(curr_sentence, curr_test_img, mean_of_esti, uncertainty, save_state=False, save_path='')

# %% [markdown]
# ### Evaluate 'ASR + Text2Pickup' model : Model should be first defined
# ### (Google Cloud Speech-To-Text API)

# %%
# Restore model

restore_path = '/content/drive/MyDrive/Speech2Pickup/Text2Pickup_model/model.ckpt'
init = tf.global_variables_initializer()
saver = tf.train.Saver()

config = tf.ConfigProto()
config.allow_soft_placement = True
config.gpu_options.allow_growth = True

T = 100

sess = tf.Session(config=config)
sess.run(init)
saver.restore(sess, restore_path)
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Speech2Pickup/Text2Pickup_model/model.ckpt

# %%
# Load data

data = np.load('/content/drive/MyDrive/Speech2Pickup/ASR_text2pickup_evaluate.npz')
img_idxs = data['img_idxs']
pos_outputs = data['pos_outputs']
real_text_inputs = data['real_text_inputs']
STT_text_inputs = data['STT_text_inputs']
num_STT_error = 0

for i in range(len(img_idxs)):
    if real_text_inputs[i] != STT_text_inputs[i]:
        num_STT_error += 1
print('STT accuracy: {}%'.format((1-(num_STT_error/len(img_idxs)))*100))
# Out:
# STT accuracy: 96.56308851224105%

# %%
# Evaluate model

import time

img_path = '/content/drive/MyDrive/Speech2Pickup/train_img'
dropout_rate = 0.1
num_test = len(img_idxs)
num_correct = 0
num_STT_error_w_result_error = 0
num_STT_error_w_result_correct = 0
correct_limit = 20 # 20 pixel (if the image size is 256x256)
error_idx = []
error = []
distances = []
times = []

for idx in range(num_test):
    print('Processing {}/{}'.format(idx+1, num_test))
    test_img_idx = img_idxs[idx]
    curr_test_img = utils.load_test_img(img_path, test_img_idx, img_resize=256, plot_flag = 0)
    real_text_input = real_text_inputs[idx]
    curr_text_input = STT_text_inputs[idx]
    curr_pos_outputs = pos_outputs[idx, :]

    curr_embed_input, curr_seq_len = utils.load_test_script(curr_text_input, w2v_model, 
                                                            dim_sentence, max_step_sentence)
    
    start = time.time()

    test_feed_dict = {ph_sen: np.tile(curr_embed_input, (T, 1, 1)), 
                      ph_sen_len: np.tile(curr_seq_len, (T, 1)),
                      ph_image: np.tile(curr_test_img, (T, 1, 1, 1)),
                      ph_dropout: dropout_rate}
    test_heatmap = sess.run(result_heatmap, feed_dict=test_feed_dict)

    test_heatmap = np.squeeze(test_heatmap)
    mean_of_esti = np.mean(test_heatmap, axis=0)
    
    mean_of_esti = resize(mean_of_esti, [256, 256], preserve_range=True)

    end = time.time()

    pose_esti = np.unravel_index(np.argmax(mean_of_esti), mean_of_esti.shape)
    pose_esti = np.flip(pose_esti)
    
    distance = np.sqrt(np.sum((pose_esti - curr_pos_outputs)**2))
    if distance < correct_limit:
        num_correct += 1
        if real_text_input != curr_text_input:
            num_STT_error_w_result_correct += 1
    else:
        error_idx.append(idx)
        error.append(distance)
        if real_text_input != curr_text_input:
            num_STT_error_w_result_error += 1
    inter_time = end - start
    times.append(inter_time)

    distances.append(distance)

accuracy = (num_correct/num_test)*100
num_errors = num_test - num_correct
print('ASR+Text2Pickup accuracy: {}%'.format(accuracy))
print('STT error contribution rate: {}%'.format((num_STT_error_w_result_error/num_errors)*100))
print('STT error ignored rate: {}%'.format((num_STT_error_w_result_correct/num_STT_error)*100))
# Out:
# Processing 1/2124
# Ready the test input script
# Processing 2/2124
# Ready the test input script
# Processing 3/2124
# Ready the test input script
# Processing 4/2124
# Ready the test input script
# Processing 5/2124
# Ready the test input script
# Processing 6/2124
# Ready the test input script
# Processing 7/2124
# Ready the test input script
# Processing 8/2124
# Ready the test input script
# Processing 9/2124
# Ready the test input script
# Processing 10/2124
# Ready the test input script
# Processing 11/2124
# Ready the test input script
# Processing 12/2124
# Ready the test input script
# Processing 13/2124
# Ready the test input script
# Processing 14/2124
# Ready the test input script
# Processing 15/2124
# Ready the test input script
# Processing 16/2124
# Ready the test input script
# Processing 17/2124
# Ready the test input script
# Processing 18/2124
# Ready the test input script
# Processing 19/2124
# Ready the test input script
# Processing 20/2124
# Ready the test input script
# Processing 21/2124
# Ready the test input script
# Processing 22/2124
# Ready the test input script
# Processing 23/2124
# Ready the test input script
# Processing 24/2124
# Ready the test input script
# Processing 25/2124
# Ready the test input script
# Processing 26/2124
# Ready the test input script
# Processing 27/2124
# Ready the test input script
# Processing 28/2124
# Ready the test input script
# Processing 29/2124
# Ready the test input script
# Processing 30/2124
# Ready the test input script
# Processing 31/2124
# Ready the test input script
# Processing 32/2124
# Ready the test input script
# Processing 33/2124
# Ready the test input script
# Processing 34/2124
# Ready the test input script
# Processing 35/2124
# Ready the test input script
# Processing 36/2124
# Ready the test input script
# Processing 37/2124
# Ready the test input script
# Processing 38/2124
# Ready the test input script
# Processing 39/2124
# Ready the test input script
# Processing 40/2124
# Ready the test input script
# Processing 41/2124
# Ready the test input script
# Processing 42/2124
# Ready the test input script
# Processing 43/2124
# Ready the test input script
# Processing 44/2124
# Ready the test input script
# Processing 45/2124
# Ready the test input script
# Processing 46/2124
# Ready the test input script
# Processing 47/2124
# Ready the test input script
# Processing 48/2124
# Ready the test input script
# Processing 49/2124
# Ready the test input script
# Processing 50/2124
# Ready the test input script
# Processing 51/2124
# Ready the test input script
# Processing 52/2124
# Ready the test input script
# Processing 53/2124
# Ready the test input script
# Processing 54/2124
# Ready the test input script
# Processing 55/2124
# Ready the test input script
# Processing 56/2124
# Ready the test input script
# Processing 57/2124
# Ready the test input script
# Processing 58/2124
# Ready the test input script
# Processing 59/2124
# Ready the test input script
# Processing 60/2124
# Ready the test input script
# Processing 61/2124
# Ready the test input script
# Processing 62/2124
# Ready the test input script
# Processing 63/2124
# Ready the test input script
# Processing 64/2124
# Ready the test input script
# Processing 65/2124
# Ready the test input script
# Processing 66/2124
# Ready the test input script
# Processing 67/2124
# Ready the test input script
# Processing 68/2124
# Ready the test input script
# Processing 69/2124
# Ready the test input script
# Processing 70/2124
# Ready the test input script
# Processing 71/2124
# Ready the test input script
# Processing 72/2124
# Ready the test input script
# Processing 73/2124
# Ready the test input script
# Processing 74/2124
# Ready the test input script
# Processing 75/2124
# Ready the test input script
# Processing 76/2124
# Ready the test input script
# Processing 77/2124
# Ready the test input script
# Processing 78/2124
# Ready the test input script
# Processing 79/2124
# Ready the test input script
# Processing 80/2124
# Ready the test input script
# Processing 81/2124
# Ready the test input script
# Processing 82/2124
# Ready the test input script
# Processing 83/2124
# Ready the test input script
# Processing 84/2124
# Ready the test input script
# Processing 85/2124
# Ready the test input script
# Processing 86/2124
# Ready the test input script
# Processing 87/2124
# Ready the test input script
# Processing 88/2124
# Ready the test input script
# Processing 89/2124
# Ready the test input script
# Processing 90/2124
# Ready the test input script
# Processing 91/2124
# Ready the test input script
# Processing 92/2124
# Ready the test input script
# Processing 93/2124
# Ready the test input script
# Processing 94/2124
# Ready the test input script
# Processing 95/2124
# Ready the test input script
# Processing 96/2124
# Ready the test input script
# Processing 97/2124
# Ready the test input script
# Processing 98/2124
# Ready the test input script
# Processing 99/2124
# Ready the test input script
# Processing 100/2124
# Ready the test input script
# Processing 101/2124
# Ready the test input script
# Processing 102/2124
# Ready the test input script
# Processing 103/2124
# Ready the test input script
# Processing 104/2124
# Ready the test input script
# Processing 105/2124
# Ready the test input script
# Processing 106/2124
# Ready the test input script
# Processing 107/2124
# Ready the test input script
# Processing 108/2124
# Ready the test input script
# Processing 109/2124
# Ready the test input script
# Processing 110/2124
# Ready the test input script
# Processing 111/2124
# Ready the test input script
# Processing 112/2124
# Ready the test input script
# Processing 113/2124
# Ready the test input script
# Processing 114/2124
# Ready the test input script
# Processing 115/2124
# Ready the test input script
# Processing 116/2124
# Ready the test input script
# Processing 117/2124
# Ready the test input script
# Processing 118/2124
# Ready the test input script
# Processing 119/2124
# Ready the test input script
# Processing 120/2124
# Ready the test input script
# Processing 121/2124
# Ready the test input script
# Processing 122/2124
# Ready the test input script
# Processing 123/2124
# Ready the test input script
# Processing 124/2124
# Ready the test input script
# Processing 125/2124
# Ready the test input script
# Processing 126/2124
# Ready the test input script
# Processing 127/2124
# Ready the test input script
# Processing 128/2124
# Ready the test input script
# Processing 129/2124
# Ready the test input script
# Processing 130/2124
# Ready the test input script
# Processing 131/2124
# Ready the test input script
# Processing 132/2124
# Ready the test input script
# Processing 133/2124
# Ready the test input script
# Processing 134/2124
# Ready the test input script
# Processing 135/2124
# Ready the test input script
# Processing 136/2124
# Ready the test input script
# Processing 137/2124
# Ready the test input script
# Processing 138/2124
# Ready the test input script
# Processing 139/2124
# Ready the test input script
# Processing 140/2124
# Ready the test input script
# Processing 141/2124
# Ready the test input script
# Processing 142/2124
# Ready the test input script
# Processing 143/2124
# Ready the test input script
# Processing 144/2124
# Ready the test input script
# Processing 145/2124
# Ready the test input script
# Processing 146/2124
# Ready the test input script
# Processing 147/2124
# Ready the test input script
# Processing 148/2124
# Ready the test input script
# Processing 149/2124
# Ready the test input script
# Processing 150/2124
# Ready the test input script
# Processing 151/2124
# Ready the test input script
# Processing 152/2124
# Ready the test input script
# Processing 153/2124
# Ready the test input script
# Processing 154/2124
# Ready the test input script
# Processing 155/2124
# Ready the test input script
# Processing 156/2124
# Ready the test input script
# Processing 157/2124
# Ready the test input script
# Processing 158/2124
# Ready the test input script
# Processing 159/2124
# Ready the test input script
# Processing 160/2124
# Ready the test input script
# Processing 161/2124
# Ready the test input script
# Processing 162/2124
# Ready the test input script
# Processing 163/2124
# Ready the test input script
# Processing 164/2124
# Ready the test input script
# Processing 165/2124
# Ready the test input script
# Processing 166/2124
# Ready the test input script
# Processing 167/2124
# Ready the test input script
# Processing 168/2124
# Ready the test input script
# Processing 169/2124
# Ready the test input script
# Processing 170/2124
# Ready the test input script
# Processing 171/2124
# Ready the test input script
# Processing 172/2124
# Ready the test input script
# Processing 173/2124
# Ready the test input script
# Processing 174/2124
# Ready the test input script
# Processing 175/2124
# Ready the test input script
# Processing 176/2124
# Ready the test input script
# Processing 177/2124
# Ready the test input script
# Processing 178/2124
# Ready the test input script
# Processing 179/2124
# Ready the test input script
# Processing 180/2124
# Ready the test input script
# Processing 181/2124
# Ready the test input script
# Processing 182/2124
# Ready the test input script
# Processing 183/2124
# Ready the test input script
# Processing 184/2124
# Ready the test input script
# Processing 185/2124
# Ready the test input script
# Processing 186/2124
# Ready the test input script
# Processing 187/2124
# Ready the test input script
# Processing 188/2124
# Ready the test input script
# Processing 189/2124
# Ready the test input script
# Processing 190/2124
# Ready the test input script
# Processing 191/2124
# Ready the test input script
# Processing 192/2124
# Ready the test input script
# Processing 193/2124
# Ready the test input script
# Processing 194/2124
# Ready the test input script
# Processing 195/2124
# Ready the test input script
# Processing 196/2124
# Ready the test input script
# Processing 197/2124
# Ready the test input script
# Processing 198/2124
# Ready the test input script
# Processing 199/2124
# Ready the test input script
# Processing 200/2124
# Ready the test input script
# Processing 201/2124
# Ready the test input script
# Processing 202/2124
# Ready the test input script
# Processing 203/2124
# Ready the test input script
# Processing 204/2124
# Ready the test input script
# Processing 205/2124
# Ready the test input script
# Processing 206/2124
# Ready the test input script
# Processing 207/2124
# Ready the test input script
# Processing 208/2124
# Ready the test input script
# Processing 209/2124
# Ready the test input script
# Processing 210/2124
# Ready the test input script
# Processing 211/2124
# Ready the test input script
# Processing 212/2124
# Ready the test input script
# Processing 213/2124
# Ready the test input script
# Processing 214/2124
# Ready the test input script
# Processing 215/2124
# Ready the test input script
# Processing 216/2124
# Ready the test input script
# Processing 217/2124
# Ready the test input script
# Processing 218/2124
# Ready the test input script
# Processing 219/2124
# Ready the test input script
# Processing 220/2124
# Ready the test input script
# Processing 221/2124
# Ready the test input script
# Processing 222/2124
# Ready the test input script
# Processing 223/2124
# Ready the test input script
# Processing 224/2124
# Ready the test input script
# Processing 225/2124
# Ready the test input script
# Processing 226/2124
# Ready the test input script
# Processing 227/2124
# Ready the test input script
# Processing 228/2124
# Ready the test input script
# Processing 229/2124
# Ready the test input script
# Processing 230/2124
# Ready the test input script
# Processing 231/2124
# Ready the test input script
# Processing 232/2124
# Ready the test input script
# Processing 233/2124
# Ready the test input script
# Processing 234/2124
# Ready the test input script
# Processing 235/2124
# Ready the test input script
# Processing 236/2124
# Ready the test input script
# Processing 237/2124
# Ready the test input script
# Processing 238/2124
# Ready the test input script
# Processing 239/2124
# Ready the test input script
# Processing 240/2124
# Ready the test input script
# Processing 241/2124
# Ready the test input script
# Processing 242/2124
# Ready the test input script
# Processing 243/2124
# Ready the test input script
# Processing 244/2124
# Ready the test input script
# Processing 245/2124
# Ready the test input script
# Processing 246/2124
# Ready the test input script
# Processing 247/2124
# Ready the test input script
# Processing 248/2124
# Ready the test input script
# Processing 249/2124
# Ready the test input script
# Processing 250/2124
# Ready the test input script
# Processing 251/2124
# Ready the test input script
# Processing 252/2124
# Ready the test input script
# Processing 253/2124
# Ready the test input script
# Processing 254/2124
# Ready the test input script
# Processing 255/2124
# Ready the test input script
# Processing 256/2124
# Ready the test input script
# Processing 257/2124
# Ready the test input script
# Processing 258/2124
# Ready the test input script
# Processing 259/2124
# Ready the test input script
# Processing 260/2124
# Ready the test input script
# Processing 261/2124
# Ready the test input script
# Processing 262/2124
# Ready the test input script
# Processing 263/2124
# Ready the test input script
# Processing 264/2124
# Ready the test input script
# Processing 265/2124
# Ready the test input script
# Processing 266/2124
# Ready the test input script
# Processing 267/2124
# Ready the test input script
# Processing 268/2124
# Ready the test input script
# Processing 269/2124
# Ready the test input script
# Processing 270/2124
# Ready the test input script
# Processing 271/2124
# Ready the test input script
# Processing 272/2124
# Ready the test input script
# Processing 273/2124
# Ready the test input script
# Processing 274/2124
# Ready the test input script
# Processing 275/2124
# Ready the test input script
# Processing 276/2124
# Ready the test input script
# Processing 277/2124
# Ready the test input script
# Processing 278/2124
# Ready the test input script
# Processing 279/2124
# Ready the test input script
# Processing 280/2124
# Ready the test input script
# Processing 281/2124
# Ready the test input script
# Processing 282/2124
# Ready the test input script
# Processing 283/2124
# Ready the test input script
# Processing 284/2124
# Ready the test input script
# Processing 285/2124
# Ready the test input script
# Processing 286/2124
# Ready the test input script
# Processing 287/2124
# Ready the test input script
# Processing 288/2124
# Ready the test input script
# Processing 289/2124
# Ready the test input script
# Processing 290/2124
# Ready the test input script
# Processing 291/2124
# Ready the test input script
# Processing 292/2124
# Ready the test input script
# Processing 293/2124
# Ready the test input script
# Processing 294/2124
# Ready the test input script
# Processing 295/2124
# Ready the test input script
# Processing 296/2124
# Ready the test input script
# Processing 297/2124
# Ready the test input script
# Processing 298/2124
# Ready the test input script
# Processing 299/2124
# Ready the test input script
# Processing 300/2124
# Ready the test input script
# Processing 301/2124
# Ready the test input script
# Processing 302/2124
# Ready the test input script
# Processing 303/2124
# Ready the test input script
# Processing 304/2124
# Ready the test input script
# Processing 305/2124
# Ready the test input script
# Processing 306/2124
# Ready the test input script
# Processing 307/2124
# Ready the test input script
# Processing 308/2124
# Ready the test input script
# Processing 309/2124
# Ready the test input script
# Processing 310/2124
# Ready the test input script
# Processing 311/2124
# Ready the test input script
# Processing 312/2124
# Ready the test input script
# Processing 313/2124
# Ready the test input script
# Processing 314/2124
# Ready the test input script
# Processing 315/2124
# Ready the test input script
# Processing 316/2124
# Ready the test input script
# Processing 317/2124
# Ready the test input script
# Processing 318/2124
# Ready the test input script
# Processing 319/2124
# Ready the test input script
# Processing 320/2124
# Ready the test input script
# Processing 321/2124
# Ready the test input script
# Processing 322/2124
# Ready the test input script
# Processing 323/2124
# Ready the test input script
# Processing 324/2124
# Ready the test input script
# Processing 325/2124
# Ready the test input script
# Processing 326/2124
# Ready the test input script
# Processing 327/2124
# Ready the test input script
# Processing 328/2124
# Ready the test input script
# Processing 329/2124
# Ready the test input script
# Processing 330/2124
# Ready the test input script
# Processing 331/2124
# Ready the test input script
# Processing 332/2124
# Ready the test input script
# Processing 333/2124
# Ready the test input script
# Processing 334/2124
# Ready the test input script
# Processing 335/2124
# Ready the test input script
# Processing 336/2124
# Ready the test input script
# Processing 337/2124
# Ready the test input script
# Processing 338/2124
# Ready the test input script
# Processing 339/2124
# Ready the test input script
# Processing 340/2124
# Ready the test input script
# Processing 341/2124
# Ready the test input script
# Processing 342/2124
# Ready the test input script
# Processing 343/2124
# Ready the test input script
# Processing 344/2124
# Ready the test input script
# Processing 345/2124
# Ready the test input script
# Processing 346/2124
# Ready the test input script
# Processing 347/2124
# Ready the test input script
# Processing 348/2124
# Ready the test input script
# Processing 349/2124
# Ready the test input script
# Processing 350/2124
# Ready the test input script
# Processing 351/2124
# Ready the test input script
# Processing 352/2124
# Ready the test input script
# Processing 353/2124
# Ready the test input script
# Processing 354/2124
# Ready the test input script
# Processing 355/2124
# Ready the test input script
# Processing 356/2124
# Ready the test input script
# Processing 357/2124
# Ready the test input script
# Processing 358/2124
# Ready the test input script
# Processing 359/2124
# Ready the test input script
# Processing 360/2124
# Ready the test input script
# Processing 361/2124
# Ready the test input script
# Processing 362/2124
# Ready the test input script
# Processing 363/2124
# Ready the test input script
# Processing 364/2124
# Ready the test input script
# Processing 365/2124
# Ready the test input script
# Processing 366/2124
# Ready the test input script
# Processing 367/2124
# Ready the test input script
# Processing 368/2124
# Ready the test input script
# Processing 369/2124
# Ready the test input script
# Processing 370/2124
# Ready the test input script
# Processing 371/2124
# Ready the test input script
# Processing 372/2124
# Ready the test input script
# Processing 373/2124
# Ready the test input script
# Processing 374/2124
# Ready the test input script
# Processing 375/2124
# Ready the test input script
# Processing 376/2124
# Ready the test input script
# Processing 377/2124
# Ready the test input script
# Processing 378/2124
# Ready the test input script
# Processing 379/2124
# Ready the test input script
# Processing 380/2124
# Ready the test input script
# Processing 381/2124
# Ready the test input script
# Processing 382/2124
# Ready the test input script
# Processing 383/2124
# Ready the test input script
# Processing 384/2124
# Ready the test input script
# Processing 385/2124
# Ready the test input script
# Processing 386/2124
# Ready the test input script
# Processing 387/2124
# Ready the test input script
# Processing 388/2124
# Ready the test input script
# Processing 389/2124
# Ready the test input script
# Processing 390/2124
# Ready the test input script
# Processing 391/2124
# Ready the test input script
# Processing 392/2124
# Ready the test input script
# Processing 393/2124
# Ready the test input script
# Processing 394/2124
# Ready the test input script
# Processing 395/2124
# Ready the test input script
# Processing 396/2124
# Ready the test input script
# Processing 397/2124
# Ready the test input script
# Processing 398/2124
# Ready the test input script
# Processing 399/2124
# Ready the test input script
# Processing 400/2124
# Ready the test input script
# Processing 401/2124
# Ready the test input script
# Processing 402/2124
# Ready the test input script
# Processing 403/2124
# Ready the test input script
# Processing 404/2124
# Ready the test input script
# Processing 405/2124
# Ready the test input script
# Processing 406/2124
# Ready the test input script
# Processing 407/2124
# Ready the test input script
# Processing 408/2124
# Ready the test input script
# Processing 409/2124
# Ready the test input script
# Processing 410/2124
# Ready the test input script
# Processing 411/2124
# Ready the test input script
# Processing 412/2124
# Ready the test input script
# Processing 413/2124
# Ready the test input script
# Processing 414/2124
# Ready the test input script
# Processing 415/2124
# Ready the test input script
# Processing 416/2124
# Ready the test input script
# Processing 417/2124
# Ready the test input script
# Processing 418/2124
# Ready the test input script
# Processing 419/2124
# Ready the test input script
# Processing 420/2124
# Ready the test input script
# Processing 421/2124
# Ready the test input script
# Processing 422/2124
# Ready the test input script
# Processing 423/2124
# Ready the test input script
# Processing 424/2124
# Ready the test input script
# Processing 425/2124
# Ready the test input script
# Processing 426/2124
# Ready the test input script
# Processing 427/2124
# Ready the test input script
# Processing 428/2124
# Ready the test input script
# Processing 429/2124
# Ready the test input script
# Processing 430/2124
# Ready the test input script
# Processing 431/2124
# Ready the test input script
# Processing 432/2124
# Ready the test input script
# Processing 433/2124
# Ready the test input script
# Processing 434/2124
# Ready the test input script
# Processing 435/2124
# Ready the test input script
# Processing 436/2124
# Ready the test input script
# Processing 437/2124
# Ready the test input script
# Processing 438/2124
# Ready the test input script
# Processing 439/2124
# Ready the test input script
# Processing 440/2124
# Ready the test input script
# Processing 441/2124
# Ready the test input script
# Processing 442/2124
# Ready the test input script
# Processing 443/2124
# Ready the test input script
# Processing 444/2124
# Ready the test input script
# Processing 445/2124
# Ready the test input script
# Processing 446/2124
# Ready the test input script
# Processing 447/2124
# Ready the test input script
# Processing 448/2124
# Ready the test input script
# Processing 449/2124
# Ready the test input script
# Processing 450/2124
# Ready the test input script
# Processing 451/2124
# Ready the test input script
# Processing 452/2124
# Ready the test input script
# Processing 453/2124
# Ready the test input script
# Processing 454/2124
# Ready the test input script
# Processing 455/2124
# Ready the test input script
# Processing 456/2124
# Ready the test input script
# Processing 457/2124
# Ready the test input script
# Processing 458/2124
# Ready the test input script
# Processing 459/2124
# Ready the test input script
# Processing 460/2124
# Ready the test input script
# Processing 461/2124
# Ready the test input script
# Processing 462/2124
# Ready the test input script
# Processing 463/2124
# Ready the test input script
# Processing 464/2124
# Ready the test input script
# Processing 465/2124
# Ready the test input script
# Processing 466/2124
# Ready the test input script
# Processing 467/2124
# Ready the test input script
# Processing 468/2124
# Ready the test input script
# Processing 469/2124
# Ready the test input script
# Processing 470/2124
# Ready the test input script
# Processing 471/2124
# Ready the test input script
# Processing 472/2124
# Ready the test input script
# Processing 473/2124
# Ready the test input script
# Processing 474/2124
# Ready the test input script
# Processing 475/2124
# Ready the test input script
# Processing 476/2124
# Ready the test input script
# Processing 477/2124
# Ready the test input script
# Processing 478/2124
# Ready the test input script
# Processing 479/2124
# Ready the test input script
# Processing 480/2124
# Ready the test input script
# Processing 481/2124
# Ready the test input script
# Processing 482/2124
# Ready the test input script
# Processing 483/2124
# Ready the test input script
# Processing 484/2124
# Ready the test input script
# Processing 485/2124
# Ready the test input script
# Processing 486/2124
# Ready the test input script
# Processing 487/2124
# Ready the test input script
# Processing 488/2124
# Ready the test input script
# Processing 489/2124
# Ready the test input script
# Processing 490/2124
# Ready the test input script
# Processing 491/2124
# Ready the test input script
# Processing 492/2124
# Ready the test input script
# Processing 493/2124
# Ready the test input script
# Processing 494/2124
# Ready the test input script
# Processing 495/2124
# Ready the test input script
# Processing 496/2124
# Ready the test input script
# Processing 497/2124
# Ready the test input script
# Processing 498/2124
# Ready the test input script
# Processing 499/2124
# Ready the test input script
# Processing 500/2124
# Ready the test input script
# Processing 501/2124
# Ready the test input script
# Processing 502/2124
# Ready the test input script
# Processing 503/2124
# Ready the test input script
# Processing 504/2124
# Ready the test input script
# Processing 505/2124
# Ready the test input script
# Processing 506/2124
# Ready the test input script
# Processing 507/2124
# Ready the test input script
# Processing 508/2124
# Ready the test input script
# Processing 509/2124
# Ready the test input script
# Processing 510/2124
# Ready the test input script
# Processing 511/2124
# Ready the test input script
# Processing 512/2124
# Ready the test input script
# Processing 513/2124
# Ready the test input script
# Processing 514/2124
# Ready the test input script
# Processing 515/2124
# Ready the test input script
# Processing 516/2124
# Ready the test input script
# Processing 517/2124
# Ready the test input script
# Processing 518/2124
# Ready the test input script
# Processing 519/2124
# Ready the test input script
# Processing 520/2124
# Ready the test input script
# Processing 521/2124
# Ready the test input script
# Processing 522/2124
# Ready the test input script
# Processing 523/2124
# Ready the test input script
# Processing 524/2124
# Ready the test input script
# Processing 525/2124
# Ready the test input script
# Processing 526/2124
# Ready the test input script
# Processing 527/2124
# Ready the test input script
# Processing 528/2124
# Ready the test input script
# Processing 529/2124
# Ready the test input script
# Processing 530/2124
# Ready the test input script
# Processing 531/2124
# Ready the test input script
# Processing 532/2124
# Ready the test input script
# Processing 533/2124
# Ready the test input script
# Processing 534/2124
# Ready the test input script
# Processing 535/2124
# Ready the test input script
# Processing 536/2124
# Ready the test input script
# Processing 537/2124
# Ready the test input script
# Processing 538/2124
# Ready the test input script
# Processing 539/2124
# Ready the test input script
# Processing 540/2124
# Ready the test input script
# Processing 541/2124
# Ready the test input script
# Processing 542/2124
# Ready the test input script
# Processing 543/2124
# Ready the test input script
# Processing 544/2124
# Ready the test input script
# Processing 545/2124
# Ready the test input script
# Processing 546/2124
# Ready the test input script
# Processing 547/2124
# Ready the test input script
# Processing 548/2124
# Ready the test input script
# Processing 549/2124
# Ready the test input script
# Processing 550/2124
# Ready the test input script
# Processing 551/2124
# Ready the test input script
# Processing 552/2124
# Ready the test input script
# Processing 553/2124
# Ready the test input script
# Processing 554/2124
# Ready the test input script
# Processing 555/2124
# Ready the test input script
# Processing 556/2124
# Ready the test input script
# Processing 557/2124
# Ready the test input script
# Processing 558/2124
# Ready the test input script
# Processing 559/2124
# Ready the test input script
# Processing 560/2124
# Ready the test input script
# Processing 561/2124
# Ready the test input script
# Processing 562/2124
# Ready the test input script
# Processing 563/2124
# Ready the test input script
# Processing 564/2124
# Ready the test input script
# Processing 565/2124
# Ready the test input script
# Processing 566/2124
# Ready the test input script
# Processing 567/2124
# Ready the test input script
# Processing 568/2124
# Ready the test input script
# Processing 569/2124
# Ready the test input script
# Processing 570/2124
# Ready the test input script
# Processing 571/2124
# Ready the test input script
# Processing 572/2124
# Ready the test input script
# Processing 573/2124
# Ready the test input script
# Processing 574/2124
# Ready the test input script
# Processing 575/2124
# Ready the test input script
# Processing 576/2124
# Ready the test input script
# Processing 577/2124
# Ready the test input script
# Processing 578/2124
# Ready the test input script
# Processing 579/2124
# Ready the test input script
# Processing 580/2124
# Ready the test input script
# Processing 581/2124
# Ready the test input script
# Processing 582/2124
# Ready the test input script
# Processing 583/2124
# Ready the test input script
# Processing 584/2124
# Ready the test input script
# Processing 585/2124
# Ready the test input script
# Processing 586/2124
# Ready the test input script
# Processing 587/2124
# Ready the test input script
# Processing 588/2124
# Ready the test input script
# Processing 589/2124
# Ready the test input script
# Processing 590/2124
# Ready the test input script
# Processing 591/2124
# Ready the test input script
# Processing 592/2124
# Ready the test input script
# Processing 593/2124
# Ready the test input script
# Processing 594/2124
# Ready the test input script
# Processing 595/2124
# Ready the test input script
# Processing 596/2124
# Ready the test input script
# Processing 597/2124
# Ready the test input script
# Processing 598/2124
# Ready the test input script
# Processing 599/2124
# Ready the test input script
# Processing 600/2124
# Ready the test input script
# Processing 601/2124
# Ready the test input script
# Processing 602/2124
# Ready the test input script
# Processing 603/2124
# Ready the test input script
# Processing 604/2124
# Ready the test input script
# Processing 605/2124
# Ready the test input script
# Processing 606/2124
# Ready the test input script
# Processing 607/2124
# Ready the test input script
# Processing 608/2124
# Ready the test input script
# Processing 609/2124
# Ready the test input script
# Processing 610/2124
# Ready the test input script
# Processing 611/2124
# Ready the test input script
# Processing 612/2124
# Ready the test input script
# Processing 613/2124
# Ready the test input script
# Processing 614/2124
# Ready the test input script
# Processing 615/2124
# Ready the test input script
# Processing 616/2124
# Ready the test input script
# Processing 617/2124
# Ready the test input script
# Processing 618/2124
# Ready the test input script
# Processing 619/2124
# Ready the test input script
# Processing 620/2124
# Ready the test input script
# Processing 621/2124
# Ready the test input script
# Processing 622/2124
# Ready the test input script
# Processing 623/2124
# Ready the test input script
# Processing 624/2124
# Ready the test input script
# Processing 625/2124
# Ready the test input script
# Processing 626/2124
# Ready the test input script
# Processing 627/2124
# Ready the test input script
# Processing 628/2124
# Ready the test input script
# Processing 629/2124
# Ready the test input script
# Processing 630/2124
# Ready the test input script
# Processing 631/2124
# Ready the test input script
# Processing 632/2124
# Ready the test input script
# Processing 633/2124
# Ready the test input script
# Processing 634/2124
# Ready the test input script
# Processing 635/2124
# Ready the test input script
# Processing 636/2124
# Ready the test input script
# Processing 637/2124
# Ready the test input script
# Processing 638/2124
# Ready the test input script
# Processing 639/2124
# Ready the test input script
# Processing 640/2124
# Ready the test input script
# Processing 641/2124
# Ready the test input script
# Processing 642/2124
# Ready the test input script
# Processing 643/2124
# Ready the test input script
# Processing 644/2124
# Ready the test input script
# Processing 645/2124
# Ready the test input script
# Processing 646/2124
# Ready the test input script
# Processing 647/2124
# Ready the test input script
# Processing 648/2124
# Ready the test input script
# Processing 649/2124
# Ready the test input script
# Processing 650/2124
# Ready the test input script
# Processing 651/2124
# Ready the test input script
# Processing 652/2124
# Ready the test input script
# Processing 653/2124
# Ready the test input script
# Processing 654/2124
# Ready the test input script
# Processing 655/2124
# Ready the test input script
# Processing 656/2124
# Ready the test input script
# Processing 657/2124
# Ready the test input script
# Processing 658/2124
# Ready the test input script
# Processing 659/2124
# Ready the test input script
# Processing 660/2124
# Ready the test input script
# Processing 661/2124
# Ready the test input script
# Processing 662/2124
# Ready the test input script
# Processing 663/2124
# Ready the test input script
# Processing 664/2124
# Ready the test input script
# Processing 665/2124
# Ready the test input script
# Processing 666/2124
# Ready the test input script
# Processing 667/2124
# Ready the test input script
# Processing 668/2124
# Ready the test input script
# Processing 669/2124
# Ready the test input script
# Processing 670/2124
# Ready the test input script
# Processing 671/2124
# Ready the test input script
# Processing 672/2124
# Ready the test input script
# Processing 673/2124
# Ready the test input script
# Processing 674/2124
# Ready the test input script
# Processing 675/2124
# Ready the test input script
# Processing 676/2124
# Ready the test input script
# Processing 677/2124
# Ready the test input script
# Processing 678/2124
# Ready the test input script
# Processing 679/2124
# Ready the test input script
# Processing 680/2124
# Ready the test input script
# Processing 681/2124
# Ready the test input script
# Processing 682/2124
# Ready the test input script
# Processing 683/2124
# Ready the test input script
# Processing 684/2124
# Ready the test input script
# Processing 685/2124
# Ready the test input script
# Processing 686/2124
# Ready the test input script
# Processing 687/2124
# Ready the test input script
# Processing 688/2124
# Ready the test input script
# Processing 689/2124
# Ready the test input script
# Processing 690/2124
# Ready the test input script
# Processing 691/2124
# Ready the test input script
# Processing 692/2124
# Ready the test input script
# Processing 693/2124
# Ready the test input script
# Processing 694/2124
# Ready the test input script
# Processing 695/2124
# Ready the test input script
# Processing 696/2124
# Ready the test input script
# Processing 697/2124
# Ready the test input script
# Processing 698/2124
# Ready the test input script
# Processing 699/2124
# Ready the test input script
# Processing 700/2124
# Ready the test input script
# Processing 701/2124
# Ready the test input script
# Processing 702/2124
# Ready the test input script
# Processing 703/2124
# Ready the test input script
# Processing 704/2124
# Ready the test input script
# Processing 705/2124
# Ready the test input script
# Processing 706/2124
# Ready the test input script
# Processing 707/2124
# Ready the test input script
# Processing 708/2124
# Ready the test input script
# Processing 709/2124
# Ready the test input script
# Processing 710/2124
# Ready the test input script
# Processing 711/2124
# Ready the test input script
# Processing 712/2124
# Ready the test input script
# Processing 713/2124
# Ready the test input script
# Processing 714/2124
# Ready the test input script
# Processing 715/2124
# Ready the test input script
# Processing 716/2124
# Ready the test input script
# Processing 717/2124
# Ready the test input script
# Processing 718/2124
# Ready the test input script
# Processing 719/2124
# Ready the test input script
# Processing 720/2124
# Ready the test input script
# Processing 721/2124
# Ready the test input script
# Processing 722/2124
# Ready the test input script
# Processing 723/2124
# Ready the test input script
# Processing 724/2124
# Ready the test input script
# Processing 725/2124
# Ready the test input script
# Processing 726/2124
# Ready the test input script
# Processing 727/2124
# Ready the test input script
# Processing 728/2124
# Ready the test input script
# Processing 729/2124
# Ready the test input script
# Processing 730/2124
# Ready the test input script
# Processing 731/2124
# Ready the test input script
# Processing 732/2124
# Ready the test input script
# Processing 733/2124
# Ready the test input script
# Processing 734/2124
# Ready the test input script
# Processing 735/2124
# Ready the test input script
# Processing 736/2124
# Ready the test input script
# Processing 737/2124
# Ready the test input script
# Processing 738/2124
# Ready the test input script
# Processing 739/2124
# Ready the test input script
# Processing 740/2124
# Ready the test input script
# Processing 741/2124
# Ready the test input script
# Processing 742/2124
# Ready the test input script
# Processing 743/2124
# Ready the test input script
# Processing 744/2124
# Ready the test input script
# Processing 745/2124
# Ready the test input script
# Processing 746/2124
# Ready the test input script
# Processing 747/2124
# Ready the test input script
# Processing 748/2124
# Ready the test input script
# Processing 749/2124
# Ready the test input script
# Processing 750/2124
# Ready the test input script
# Processing 751/2124
# Ready the test input script
# Processing 752/2124
# Ready the test input script
# Processing 753/2124
# Ready the test input script
# Processing 754/2124
# Ready the test input script
# Processing 755/2124
# Ready the test input script
# Processing 756/2124
# Ready the test input script
# Processing 757/2124
# Ready the test input script
# Processing 758/2124
# Ready the test input script
# Processing 759/2124
# Ready the test input script
# Processing 760/2124
# Ready the test input script
# Processing 761/2124
# Ready the test input script
# Processing 762/2124
# Ready the test input script
# Processing 763/2124
# Ready the test input script
# Processing 764/2124
# Ready the test input script
# Processing 765/2124
# Ready the test input script
# Processing 766/2124
# Ready the test input script
# Processing 767/2124
# Ready the test input script
# Processing 768/2124
# Ready the test input script
# Processing 769/2124
# Ready the test input script
# Processing 770/2124
# Ready the test input script
# Processing 771/2124
# Ready the test input script
# Processing 772/2124
# Ready the test input script
# Processing 773/2124
# Ready the test input script
# Processing 774/2124
# Ready the test input script
# Processing 775/2124
# Ready the test input script
# Processing 776/2124
# Ready the test input script
# Processing 777/2124
# Ready the test input script
# Processing 778/2124
# Ready the test input script
# Processing 779/2124
# Ready the test input script
# Processing 780/2124
# Ready the test input script
# Processing 781/2124
# Ready the test input script
# Processing 782/2124
# Ready the test input script
# Processing 783/2124
# Ready the test input script
# Processing 784/2124
# Ready the test input script
# Processing 785/2124
# Ready the test input script
# Processing 786/2124
# Ready the test input script
# Processing 787/2124
# Ready the test input script
# Processing 788/2124
# Ready the test input script
# Processing 789/2124
# Ready the test input script
# Processing 790/2124
# Ready the test input script
# Processing 791/2124
# Ready the test input script
# Processing 792/2124
# Ready the test input script
# Processing 793/2124
# Ready the test input script
# Processing 794/2124
# Ready the test input script
# Processing 795/2124
# Ready the test input script
# Processing 796/2124
# Ready the test input script
# Processing 797/2124
# Ready the test input script
# Processing 798/2124
# Ready the test input script
# Processing 799/2124
# Ready the test input script
# Processing 800/2124
# Ready the test input script
# Processing 801/2124
# Ready the test input script
# Processing 802/2124
# Ready the test input script
# Processing 803/2124
# Ready the test input script
# Processing 804/2124
# Ready the test input script
# Processing 805/2124
# Ready the test input script
# Processing 806/2124
# Ready the test input script
# Processing 807/2124
# Ready the test input script
# Processing 808/2124
# Ready the test input script
# Processing 809/2124
# Ready the test input script
# Processing 810/2124
# Ready the test input script
# Processing 811/2124
# Ready the test input script
# Processing 812/2124
# Ready the test input script
# Processing 813/2124
# Ready the test input script
# Processing 814/2124
# Ready the test input script
# Processing 815/2124
# Ready the test input script
# Processing 816/2124
# Ready the test input script
# Processing 817/2124
# Ready the test input script
# Processing 818/2124
# Ready the test input script
# Processing 819/2124
# Ready the test input script
# Processing 820/2124
# Ready the test input script
# Processing 821/2124
# Ready the test input script
# Processing 822/2124
# Ready the test input script
# Processing 823/2124
# Ready the test input script
# Processing 824/2124
# Ready the test input script
# Processing 825/2124
# Ready the test input script
# Processing 826/2124
# Ready the test input script
# Processing 827/2124
# Ready the test input script
# Processing 828/2124
# Ready the test input script
# Processing 829/2124
# Ready the test input script
# Processing 830/2124
# Ready the test input script
# Processing 831/2124
# Ready the test input script
# Processing 832/2124
# Ready the test input script
# Processing 833/2124
# Ready the test input script
# Processing 834/2124
# Ready the test input script
# Processing 835/2124
# Ready the test input script
# Processing 836/2124
# Ready the test input script
# Processing 837/2124
# Ready the test input script
# Processing 838/2124
# Ready the test input script
# Processing 839/2124
# Ready the test input script
# Processing 840/2124
# Ready the test input script
# Processing 841/2124
# Ready the test input script
# Processing 842/2124
# Ready the test input script
# Processing 843/2124
# Ready the test input script
# Processing 844/2124
# Ready the test input script
# Processing 845/2124
# Ready the test input script
# Processing 846/2124
# Ready the test input script
# Processing 847/2124
# Ready the test input script
# Processing 848/2124
# Ready the test input script
# Processing 849/2124
# Ready the test input script
# Processing 850/2124
# Ready the test input script
# Processing 851/2124
# Ready the test input script
# Processing 852/2124
# Ready the test input script
# Processing 853/2124
# Ready the test input script
# Processing 854/2124
# Ready the test input script
# Processing 855/2124
# Ready the test input script
# Processing 856/2124
# Ready the test input script
# Processing 857/2124
# Ready the test input script
# Processing 858/2124
# Ready the test input script
# Processing 859/2124
# Ready the test input script
# Processing 860/2124
# Ready the test input script
# Processing 861/2124
# Ready the test input script
# Processing 862/2124
# Ready the test input script
# Processing 863/2124
# Ready the test input script
# Processing 864/2124
# Ready the test input script
# Processing 865/2124
# Ready the test input script
# Processing 866/2124
# Ready the test input script
# Processing 867/2124
# Ready the test input script
# Processing 868/2124
# Ready the test input script
# Processing 869/2124
# Ready the test input script
# Processing 870/2124
# Ready the test input script
# Processing 871/2124
# Ready the test input script
# Processing 872/2124
# Ready the test input script
# Processing 873/2124
# Ready the test input script
# Processing 874/2124
# Ready the test input script
# Processing 875/2124
# Ready the test input script
# Processing 876/2124
# Ready the test input script
# Processing 877/2124
# Ready the test input script
# Processing 878/2124
# Ready the test input script
# Processing 879/2124
# Ready the test input script
# Processing 880/2124
# Ready the test input script
# Processing 881/2124
# Ready the test input script
# Processing 882/2124
# Ready the test input script
# Processing 883/2124
# Ready the test input script
# Processing 884/2124
# Ready the test input script
# Processing 885/2124
# Ready the test input script
# Processing 886/2124
# Ready the test input script
# Processing 887/2124
# Ready the test input script
# Processing 888/2124
# Ready the test input script
# Processing 889/2124
# Ready the test input script
# Processing 890/2124
# Ready the test input script
# Processing 891/2124
# Ready the test input script
# Processing 892/2124
# Ready the test input script
# Processing 893/2124
# Ready the test input script
# Processing 894/2124
# Ready the test input script
# Processing 895/2124
# Ready the test input script
# Processing 896/2124
# Ready the test input script
# Processing 897/2124
# Ready the test input script
# Processing 898/2124
# Ready the test input script
# Processing 899/2124
# Ready the test input script
# Processing 900/2124
# Ready the test input script
# Processing 901/2124
# Ready the test input script
# Processing 902/2124
# Ready the test input script
# Processing 903/2124
# Ready the test input script
# Processing 904/2124
# Ready the test input script
# Processing 905/2124
# Ready the test input script
# Processing 906/2124
# Ready the test input script
# Processing 907/2124
# Ready the test input script
# Processing 908/2124
# Ready the test input script
# Processing 909/2124
# Ready the test input script
# Processing 910/2124
# Ready the test input script
# Processing 911/2124
# Ready the test input script
# Processing 912/2124
# Ready the test input script
# Processing 913/2124
# Ready the test input script
# Processing 914/2124
# Ready the test input script
# Processing 915/2124
# Ready the test input script
# Processing 916/2124
# Ready the test input script
# Processing 917/2124
# Ready the test input script
# Processing 918/2124
# Ready the test input script
# Processing 919/2124
# Ready the test input script
# Processing 920/2124
# Ready the test input script
# Processing 921/2124
# Ready the test input script
# Processing 922/2124
# Ready the test input script
# Processing 923/2124
# Ready the test input script
# Processing 924/2124
# Ready the test input script
# Processing 925/2124
# Ready the test input script
# Processing 926/2124
# Ready the test input script
# Processing 927/2124
# Ready the test input script
# Processing 928/2124
# Ready the test input script
# Processing 929/2124
# Ready the test input script
# Processing 930/2124
# Ready the test input script
# Processing 931/2124
# Ready the test input script
# Processing 932/2124
# Ready the test input script
# Processing 933/2124
# Ready the test input script
# Processing 934/2124
# Ready the test input script
# Processing 935/2124
# Ready the test input script
# Processing 936/2124
# Ready the test input script
# Processing 937/2124
# Ready the test input script
# Processing 938/2124
# Ready the test input script
# Processing 939/2124
# Ready the test input script
# Processing 940/2124
# Ready the test input script
# Processing 941/2124
# Ready the test input script
# Processing 942/2124
# Ready the test input script
# Processing 943/2124
# Ready the test input script
# Processing 944/2124
# Ready the test input script
# Processing 945/2124
# Ready the test input script
# Processing 946/2124
# Ready the test input script
# Processing 947/2124
# Ready the test input script
# Processing 948/2124
# Ready the test input script
# Processing 949/2124
# Ready the test input script
# Processing 950/2124
# Ready the test input script
# Processing 951/2124
# Ready the test input script
# Processing 952/2124
# Ready the test input script
# Processing 953/2124
# Ready the test input script
# Processing 954/2124
# Ready the test input script
# Processing 955/2124
# Ready the test input script
# Processing 956/2124
# Ready the test input script
# Processing 957/2124
# Ready the test input script
# Processing 958/2124
# Ready the test input script
# Processing 959/2124
# Ready the test input script
# Processing 960/2124
# Ready the test input script
# Processing 961/2124
# Ready the test input script
# Processing 962/2124
# Ready the test input script
# Processing 963/2124
# Ready the test input script
# Processing 964/2124
# Ready the test input script
# Processing 965/2124
# Ready the test input script
# Processing 966/2124
# Ready the test input script
# Processing 967/2124
# Ready the test input script
# Processing 968/2124
# Ready the test input script
# Processing 969/2124
# Ready the test input script
# Processing 970/2124
# Ready the test input script
# Processing 971/2124
# Ready the test input script
# Processing 972/2124
# Ready the test input script
# Processing 973/2124
# Ready the test input script
# Processing 974/2124
# Ready the test input script
# Processing 975/2124
# Ready the test input script
# Processing 976/2124
# Ready the test input script
# Processing 977/2124
# Ready the test input script
# Processing 978/2124
# Ready the test input script
# Processing 979/2124
# Ready the test input script
# Processing 980/2124
# Ready the test input script
# Processing 981/2124
# Ready the test input script
# Processing 982/2124
# Ready the test input script
# Processing 983/2124
# Ready the test input script
# Processing 984/2124
# Ready the test input script
# Processing 985/2124
# Ready the test input script
# Processing 986/2124
# Ready the test input script
# Processing 987/2124
# Ready the test input script
# Processing 988/2124
# Ready the test input script
# Processing 989/2124
# Ready the test input script
# Processing 990/2124
# Ready the test input script
# Processing 991/2124
# Ready the test input script
# Processing 992/2124
# Ready the test input script
# Processing 993/2124
# Ready the test input script
# Processing 994/2124
# Ready the test input script
# Processing 995/2124
# Ready the test input script
# Processing 996/2124
# Ready the test input script
# Processing 997/2124
# Ready the test input script
# Processing 998/2124
# Ready the test input script
# Processing 999/2124
# Ready the test input script
# Processing 1000/2124
# Ready the test input script
# Processing 1001/2124
# Ready the test input script
# Processing 1002/2124
# Ready the test input script
# ...
# Ready the test input script
# Processing 1802/2124
# Ready the test input script
# Processing 1803/2124
# Ready the test input script
# Processing 1804/2124
# Ready the test input script
# Processing 1805/2124
# Ready the test input script
# Processing 1806/2124
# Ready the test input script
# Processing 1807/2124
# Ready the test input script
# Processing 1808/2124
# Ready the test input script
# Processing 1809/2124
# Ready the test input script
# Processing 1810/2124
# Ready the test input script
# Processing 1811/2124
# Ready the test input script
# Processing 1812/2124
# Ready the test input script
# Processing 1813/2124
# Ready the test input script
# Processing 1814/2124
# Ready the test input script
# Processing 1815/2124
# Ready the test input script
# Processing 1816/2124
# Ready the test input script
# Processing 1817/2124
# Ready the test input script
# Processing 1818/2124
# Ready the test input script
# Processing 1819/2124
# Ready the test input script
# Processing 1820/2124
# Ready the test input script
# Processing 1821/2124
# Ready the test input script
# Processing 1822/2124
# Ready the test input script
# Processing 1823/2124
# Ready the test input script
# Processing 1824/2124
# Ready the test input script
# Processing 1825/2124
# Ready the test input script
# Processing 1826/2124
# Ready the test input script
# Processing 1827/2124
# Ready the test input script
# Processing 1828/2124
# Ready the test input script
# Processing 1829/2124
# Ready the test input script
# Processing 1830/2124
# Ready the test input script
# Processing 1831/2124
# Ready the test input script
# Processing 1832/2124
# Ready the test input script
# Processing 1833/2124
# Ready the test input script
# Processing 1834/2124
# Ready the test input script
# Processing 1835/2124
# Ready the test input script
# Processing 1836/2124
# Ready the test input script
# Processing 1837/2124
# Ready the test input script
# Processing 1838/2124
# Ready the test input script
# Processing 1839/2124
# Ready the test input script
# Processing 1840/2124
# Ready the test input script
# Processing 1841/2124
# Ready the test input script
# Processing 1842/2124
# Ready the test input script
# Processing 1843/2124
# Ready the test input script
# Processing 1844/2124
# Ready the test input script
# Processing 1845/2124
# Ready the test input script
# Processing 1846/2124
# Ready the test input script
# Processing 1847/2124
# Ready the test input script
# Processing 1848/2124
# Ready the test input script
# Processing 1849/2124
# Ready the test input script
# Processing 1850/2124
# Ready the test input script
# Processing 1851/2124
# Ready the test input script
# Processing 1852/2124
# Ready the test input script
# Processing 1853/2124
# Ready the test input script
# Processing 1854/2124
# Ready the test input script
# Processing 1855/2124
# Ready the test input script
# Processing 1856/2124
# Ready the test input script
# Processing 1857/2124
# Ready the test input script
# Processing 1858/2124
# Ready the test input script
# Processing 1859/2124
# Ready the test input script
# Processing 1860/2124
# Ready the test input script
# Processing 1861/2124
# Ready the test input script
# Processing 1862/2124
# Ready the test input script
# Processing 1863/2124
# Ready the test input script
# Processing 1864/2124
# Ready the test input script
# Processing 1865/2124
# Ready the test input script
# Processing 1866/2124
# Ready the test input script
# Processing 1867/2124
# Ready the test input script
# Processing 1868/2124
# Ready the test input script
# Processing 1869/2124
# Ready the test input script
# Processing 1870/2124
# Ready the test input script
# Processing 1871/2124
# Ready the test input script
# Processing 1872/2124
# Ready the test input script
# Processing 1873/2124
# Ready the test input script
# Processing 1874/2124
# Ready the test input script
# Processing 1875/2124
# Ready the test input script
# Processing 1876/2124
# Ready the test input script
# Processing 1877/2124
# Ready the test input script
# Processing 1878/2124
# Ready the test input script
# Processing 1879/2124
# Ready the test input script
# Processing 1880/2124
# Ready the test input script
# Processing 1881/2124
# Ready the test input script
# Processing 1882/2124
# Ready the test input script
# Processing 1883/2124
# Ready the test input script
# Processing 1884/2124
# Ready the test input script
# Processing 1885/2124
# Ready the test input script
# Processing 1886/2124
# Ready the test input script
# Processing 1887/2124
# Ready the test input script
# Processing 1888/2124
# Ready the test input script
# Processing 1889/2124
# Ready the test input script
# Processing 1890/2124
# Ready the test input script
# Processing 1891/2124
# Ready the test input script
# Processing 1892/2124
# Ready the test input script
# Processing 1893/2124
# Ready the test input script
# Processing 1894/2124
# Ready the test input script
# Processing 1895/2124
# Ready the test input script
# Processing 1896/2124
# Ready the test input script
# Processing 1897/2124
# Ready the test input script
# Processing 1898/2124
# Ready the test input script
# Processing 1899/2124
# Ready the test input script
# Processing 1900/2124
# Ready the test input script
# Processing 1901/2124
# Ready the test input script
# Processing 1902/2124
# Ready the test input script
# Processing 1903/2124
# Ready the test input script
# Processing 1904/2124
# Ready the test input script
# Processing 1905/2124
# Ready the test input script
# Processing 1906/2124
# Ready the test input script
# Processing 1907/2124
# Ready the test input script
# Processing 1908/2124
# Ready the test input script
# Processing 1909/2124
# Ready the test input script
# Processing 1910/2124
# Ready the test input script
# Processing 1911/2124
# Ready the test input script
# Processing 1912/2124
# Ready the test input script
# Processing 1913/2124
# Ready the test input script
# Processing 1914/2124
# Ready the test input script
# Processing 1915/2124
# Ready the test input script
# Processing 1916/2124
# Ready the test input script
# Processing 1917/2124
# Ready the test input script
# Processing 1918/2124
# Ready the test input script
# Processing 1919/2124
# Ready the test input script
# Processing 1920/2124
# Ready the test input script
# Processing 1921/2124
# Ready the test input script
# Processing 1922/2124
# Ready the test input script
# Processing 1923/2124
# Ready the test input script
# Processing 1924/2124
# Ready the test input script
# Processing 1925/2124
# Ready the test input script
# Processing 1926/2124
# Ready the test input script
# Processing 1927/2124
# Ready the test input script
# Processing 1928/2124
# Ready the test input script
# Processing 1929/2124
# Ready the test input script
# Processing 1930/2124
# Ready the test input script
# Processing 1931/2124
# Ready the test input script
# Processing 1932/2124
# Ready the test input script
# Processing 1933/2124
# Ready the test input script
# Processing 1934/2124
# Ready the test input script
# Processing 1935/2124
# Ready the test input script
# Processing 1936/2124
# Ready the test input script
# Processing 1937/2124
# Ready the test input script
# Processing 1938/2124
# Ready the test input script
# Processing 1939/2124
# Ready the test input script
# Processing 1940/2124
# Ready the test input script
# Processing 1941/2124
# Ready the test input script
# Processing 1942/2124
# Ready the test input script
# Processing 1943/2124
# Ready the test input script
# Processing 1944/2124
# Ready the test input script
# Processing 1945/2124
# Ready the test input script
# Processing 1946/2124
# Ready the test input script
# Processing 1947/2124
# Ready the test input script
# Processing 1948/2124
# Ready the test input script
# Processing 1949/2124
# Ready the test input script
# Processing 1950/2124
# Ready the test input script
# Processing 1951/2124
# Ready the test input script
# Processing 1952/2124
# Ready the test input script
# Processing 1953/2124
# Ready the test input script
# Processing 1954/2124
# Ready the test input script
# Processing 1955/2124
# Ready the test input script
# Processing 1956/2124
# Ready the test input script
# Processing 1957/2124
# Ready the test input script
# Processing 1958/2124
# Ready the test input script
# Processing 1959/2124
# Ready the test input script
# Processing 1960/2124
# Ready the test input script
# Processing 1961/2124
# Ready the test input script
# Processing 1962/2124
# Ready the test input script
# Processing 1963/2124
# Ready the test input script
# Processing 1964/2124
# Ready the test input script
# Processing 1965/2124
# Ready the test input script
# Processing 1966/2124
# Ready the test input script
# Processing 1967/2124
# Ready the test input script
# Processing 1968/2124
# Ready the test input script
# Processing 1969/2124
# Ready the test input script
# Processing 1970/2124
# Ready the test input script
# Processing 1971/2124
# Ready the test input script
# Processing 1972/2124
# Ready the test input script
# Processing 1973/2124
# Ready the test input script
# Processing 1974/2124
# Ready the test input script
# Processing 1975/2124
# Ready the test input script
# Processing 1976/2124
# Ready the test input script
# Processing 1977/2124
# Ready the test input script
# Processing 1978/2124
# Ready the test input script
# Processing 1979/2124
# Ready the test input script
# Processing 1980/2124
# Ready the test input script
# Processing 1981/2124
# Ready the test input script
# Processing 1982/2124
# Ready the test input script
# Processing 1983/2124
# Ready the test input script
# Processing 1984/2124
# Ready the test input script
# Processing 1985/2124
# Ready the test input script
# Processing 1986/2124
# Ready the test input script
# Processing 1987/2124
# Ready the test input script
# Processing 1988/2124
# Ready the test input script
# Processing 1989/2124
# Ready the test input script
# Processing 1990/2124
# Ready the test input script
# Processing 1991/2124
# Ready the test input script
# Processing 1992/2124
# Ready the test input script
# Processing 1993/2124
# Ready the test input script
# Processing 1994/2124
# Ready the test input script
# Processing 1995/2124
# Ready the test input script
# Processing 1996/2124
# Ready the test input script
# Processing 1997/2124
# Ready the test input script
# Processing 1998/2124
# Ready the test input script
# Processing 1999/2124
# Ready the test input script
# Processing 2000/2124
# Ready the test input script
# Processing 2001/2124
# Ready the test input script
# Processing 2002/2124
# Ready the test input script
# Processing 2003/2124
# Ready the test input script
# Processing 2004/2124
# Ready the test input script
# Processing 2005/2124
# Ready the test input script
# Processing 2006/2124
# Ready the test input script
# Processing 2007/2124
# Ready the test input script
# Processing 2008/2124
# Ready the test input script
# Processing 2009/2124
# Ready the test input script
# Processing 2010/2124
# Ready the test input script
# Processing 2011/2124
# Ready the test input script
# Processing 2012/2124
# Ready the test input script
# Processing 2013/2124
# Ready the test input script
# Processing 2014/2124
# Ready the test input script
# Processing 2015/2124
# Ready the test input script
# Processing 2016/2124
# Ready the test input script
# Processing 2017/2124
# Ready the test input script
# Processing 2018/2124
# Ready the test input script
# Processing 2019/2124
# Ready the test input script
# Processing 2020/2124
# Ready the test input script
# Processing 2021/2124
# Ready the test input script
# Processing 2022/2124
# Ready the test input script
# Processing 2023/2124
# Ready the test input script
# Processing 2024/2124
# Ready the test input script
# Processing 2025/2124
# Ready the test input script
# Processing 2026/2124
# Ready the test input script
# Processing 2027/2124
# Ready the test input script
# Processing 2028/2124
# Ready the test input script
# Processing 2029/2124
# Ready the test input script
# Processing 2030/2124
# Ready the test input script
# Processing 2031/2124
# Ready the test input script
# Processing 2032/2124
# Ready the test input script
# Processing 2033/2124
# Ready the test input script
# Processing 2034/2124
# Ready the test input script
# Processing 2035/2124
# Ready the test input script
# Processing 2036/2124
# Ready the test input script
# Processing 2037/2124
# Ready the test input script
# Processing 2038/2124
# Ready the test input script
# Processing 2039/2124
# Ready the test input script
# Processing 2040/2124
# Ready the test input script
# Processing 2041/2124
# Ready the test input script
# Processing 2042/2124
# Ready the test input script
# Processing 2043/2124
# Ready the test input script
# Processing 2044/2124
# Ready the test input script
# Processing 2045/2124
# Ready the test input script
# Processing 2046/2124
# Ready the test input script
# Processing 2047/2124
# Ready the test input script
# Processing 2048/2124
# Ready the test input script
# Processing 2049/2124
# Ready the test input script
# Processing 2050/2124
# Ready the test input script
# Processing 2051/2124
# Ready the test input script
# Processing 2052/2124
# Ready the test input script
# Processing 2053/2124
# Ready the test input script
# Processing 2054/2124
# Ready the test input script
# Processing 2055/2124
# Ready the test input script
# Processing 2056/2124
# Ready the test input script
# Processing 2057/2124
# Ready the test input script
# Processing 2058/2124
# Ready the test input script
# Processing 2059/2124
# Ready the test input script
# Processing 2060/2124
# Ready the test input script
# Processing 2061/2124
# Ready the test input script
# Processing 2062/2124
# Ready the test input script
# Processing 2063/2124
# Ready the test input script
# Processing 2064/2124
# Ready the test input script
# Processing 2065/2124
# Ready the test input script
# Processing 2066/2124
# Ready the test input script
# Processing 2067/2124
# Ready the test input script
# Processing 2068/2124
# Ready the test input script
# Processing 2069/2124
# Ready the test input script
# Processing 2070/2124
# Ready the test input script
# Processing 2071/2124
# Ready the test input script
# Processing 2072/2124
# Ready the test input script
# Processing 2073/2124
# Ready the test input script
# Processing 2074/2124
# Ready the test input script
# Processing 2075/2124
# Ready the test input script
# Processing 2076/2124
# Ready the test input script
# Processing 2077/2124
# Ready the test input script
# Processing 2078/2124
# Ready the test input script
# Processing 2079/2124
# Ready the test input script
# Processing 2080/2124
# Ready the test input script
# Processing 2081/2124
# Ready the test input script
# Processing 2082/2124
# Ready the test input script
# Processing 2083/2124
# Ready the test input script
# Processing 2084/2124
# Ready the test input script
# Processing 2085/2124
# Ready the test input script
# Processing 2086/2124
# Ready the test input script
# Processing 2087/2124
# Ready the test input script
# Processing 2088/2124
# Ready the test input script
# Processing 2089/2124
# Ready the test input script
# Processing 2090/2124
# Ready the test input script
# Processing 2091/2124
# Ready the test input script
# Processing 2092/2124
# Ready the test input script
# Processing 2093/2124
# Ready the test input script
# Processing 2094/2124
# Ready the test input script
# Processing 2095/2124
# Ready the test input script
# Processing 2096/2124
# Ready the test input script
# Processing 2097/2124
# Ready the test input script
# Processing 2098/2124
# Ready the test input script
# Processing 2099/2124
# Ready the test input script
# Processing 2100/2124
# Ready the test input script
# Processing 2101/2124
# Ready the test input script
# Processing 2102/2124
# Ready the test input script
# Processing 2103/2124
# Ready the test input script
# Processing 2104/2124
# Ready the test input script
# Processing 2105/2124
# Ready the test input script
# Processing 2106/2124
# Ready the test input script
# Processing 2107/2124
# Ready the test input script
# Processing 2108/2124
# Ready the test input script
# Processing 2109/2124
# Ready the test input script
# Processing 2110/2124
# Ready the test input script
# Processing 2111/2124
# Ready the test input script
# Processing 2112/2124
# Ready the test input script
# Processing 2113/2124
# Ready the test input script
# Processing 2114/2124
# Ready the test input script
# Processing 2115/2124
# Ready the test input script
# Processing 2116/2124
# Ready the test input script
# Processing 2117/2124
# Ready the test input script
# Processing 2118/2124
# Ready the test input script
# Processing 2119/2124
# Ready the test input script
# Processing 2120/2124
# Ready the test input script
# Processing 2121/2124
# Ready the test input script
# Processing 2122/2124
# Ready the test input script
# Processing 2123/2124
# Ready the test input script
# Processing 2124/2124
# Ready the test input script
# ASR+Text2Pickup accuracy: 98.6346516007533%
# STT error contribution rate: 41.37931034482759%
# STT error ignored rate: 83.56164383561644%

# %%
# Plot error distance

import matplotlib.pyplot as plt

plt.plot(error)

# %%
# Evaluate model inference time

times = np.asarray(times)
STT_compute_times = np.load('/content/drive/MyDrive/Speech2Pickup/ASR_STT_time_evaluate.npz')['times']
taken_times_final = times + STT_compute_times

Q1 = np.percentile(taken_times_final, 25)
Q2 = np.percentile(taken_times_final, 50)
Q3 = np.percentile(taken_times_final, 75)
std = np.std(taken_times_final)
print('Q1: {}, Q2: {}, Q3: {}, std: {}'.format(Q1, Q2, Q3, std))
# Out:
# Q1: 1.0075035095214844, Q2: 1.2062181234359741, Q3: 1.2876365780830383, std: 0.2920183382884107

# %%
# Evaluate model inference error (distance)

print('mean: {}, std: {}'.format(np.mean(distances), np.std(distances)))
# Out:
# mean: 5.742909380878183, std: 9.025214174821658

# %%
# Evaluate model inference error (error)

print('mean: {}, std: {}'.format(np.mean(error), np.std(error)))
# Out:
# mean: 68.70117080029898, std: 40.34990270012463

# %% [markdown]
# ### Evaluate 'ASR + Text2Pickup' model : Model should be first defined
# ### (DeepSpeech2)

# %%
# Restore model

restore_path = '/content/drive/MyDrive/Speech2Pickup/Text2Pickup_model/model.ckpt'
init = tf.global_variables_initializer()
saver = tf.train.Saver()

config = tf.ConfigProto()
config.allow_soft_placement = True
config.gpu_options.allow_growth = True

T = 100

sess = tf.Session(config=config)
sess.run(init)
saver.restore(sess, restore_path)
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Speech2Pickup/Text2Pickup_model/model.ckpt

# %%
# Load data

data = np.load('/content/drive/MyDrive/Speech2Pickup/ASR_deepspeech2_text2pickup_evaluate.npz')
img_idxs = data['img_idxs']
pos_outputs = data['pos_outputs']
real_text_inputs = data['real_text_inputs']
STT_text_inputs = data['STT_text_inputs']
num_STT_error = 0

for i in range(len(img_idxs)):
    if real_text_inputs[i] != STT_text_inputs[i]:
        num_STT_error += 1
print('STT accuracy: {}%'.format((1-(num_STT_error/len(img_idxs)))*100))
# Out:
# STT accuracy: 77.11864406779661%

# %%
# Evaluate model

img_path = '/content/drive/MyDrive/Speech2Pickup/train_img'
dropout_rate = 0.1
num_test = len(img_idxs)
num_correct = 0
num_STT_error_w_result_error = 0
num_STT_error_w_result_correct = 0
correct_limit = 20 # 20 pixel (if the image size is 256x256)
error_idx = []
distances = []
error = []
times = []

for idx in range(num_test):
    print('Processing {}/{}'.format(idx+1, num_test))
    test_img_idx = img_idxs[idx]
    curr_test_img = utils.load_test_img(img_path, test_img_idx, img_resize=256, plot_flag = 0)
    real_text_input = real_text_inputs[idx]
    curr_text_input = STT_text_inputs[idx]
    curr_pos_outputs = pos_outputs[idx, :]

    curr_embed_input, curr_seq_len = utils.load_test_script(curr_text_input, w2v_model, 
                                                            dim_sentence, max_step_sentence)
    
    start = time.time()

    test_feed_dict = {ph_sen: np.tile(curr_embed_input, (T, 1, 1)), 
                      ph_sen_len: np.tile(curr_seq_len, (T, 1)),
                      ph_image: np.tile(curr_test_img, (T, 1, 1, 1)),
                      ph_dropout: dropout_rate}
    test_heatmap = sess.run(result_heatmap, feed_dict=test_feed_dict)

    test_heatmap = np.squeeze(test_heatmap)
    mean_of_esti = np.mean(test_heatmap, axis=0)
    
    mean_of_esti = resize(mean_of_esti, [256, 256], preserve_range=True)

    end = time.time()

    pose_esti = np.unravel_index(np.argmax(mean_of_esti), mean_of_esti.shape)
    pose_esti = np.flip(pose_esti)
    
    distance = np.sqrt(np.sum((pose_esti - curr_pos_outputs)**2))
    if distance < correct_limit:
        num_correct += 1
        if real_text_input != curr_text_input:
            num_STT_error_w_result_correct += 1
    else:
        error_idx.append(idx)
        error.append(distance)
        if real_text_input != curr_text_input:
            num_STT_error_w_result_error += 1
    inter_time = end - start
    times.append(inter_time)

    distances.append(distance)

accuracy = (num_correct/num_test)*100
num_errors = num_test - num_correct
print('ASR+Text2Pickup accuracy: {}%'.format(accuracy))
print('STT error contribution rate: {}%'.format((num_STT_error_w_result_error/num_errors)*100))
print('STT error ignored rate: {}%'.format((num_STT_error_w_result_correct/num_STT_error)*100))
# Out:
# Processing 1/2124
# Ready the test input script
# Processing 2/2124
# Ready the test input script
# Processing 3/2124
# Ready the test input script
# Processing 4/2124
# Ready the test input script
# Processing 5/2124
# Ready the test input script
# Processing 6/2124
# Ready the test input script
# Processing 7/2124
# Ready the test input script
# Processing 8/2124
# Ready the test input script
# Processing 9/2124
# Ready the test input script
# Processing 10/2124
# Ready the test input script
# Processing 11/2124
# Ready the test input script
# Processing 12/2124
# Ready the test input script
# Processing 13/2124
# Ready the test input script
# Processing 14/2124
# Ready the test input script
# Processing 15/2124
# Ready the test input script
# Processing 16/2124
# Ready the test input script
# Processing 17/2124
# Ready the test input script
# Processing 18/2124
# Ready the test input script
# Processing 19/2124
# Ready the test input script
# Processing 20/2124
# Ready the test input script
# Processing 21/2124
# Ready the test input script
# Processing 22/2124
# Ready the test input script
# Processing 23/2124
# Ready the test input script
# Processing 24/2124
# Ready the test input script
# Processing 25/2124
# Ready the test input script
# Processing 26/2124
# Ready the test input script
# Processing 27/2124
# Ready the test input script
# Processing 28/2124
# Ready the test input script
# Processing 29/2124
# Ready the test input script
# Processing 30/2124
# Ready the test input script
# Processing 31/2124
# Ready the test input script
# Processing 32/2124
# Ready the test input script
# Processing 33/2124
# Ready the test input script
# Processing 34/2124
# Ready the test input script
# Processing 35/2124
# Ready the test input script
# Processing 36/2124
# Ready the test input script
# Processing 37/2124
# Ready the test input script
# Processing 38/2124
# Ready the test input script
# Processing 39/2124
# Ready the test input script
# Processing 40/2124
# Ready the test input script
# Processing 41/2124
# Ready the test input script
# Processing 42/2124
# Ready the test input script
# Processing 43/2124
# Ready the test input script
# Processing 44/2124
# Ready the test input script
# Processing 45/2124
# Ready the test input script
# Processing 46/2124
# Ready the test input script
# Processing 47/2124
# Ready the test input script
# Processing 48/2124
# Ready the test input script
# Processing 49/2124
# Ready the test input script
# Processing 50/2124
# Ready the test input script
# Processing 51/2124
# Ready the test input script
# Processing 52/2124
# Ready the test input script
# Processing 53/2124
# Ready the test input script
# Processing 54/2124
# Ready the test input script
# Processing 55/2124
# Ready the test input script
# Processing 56/2124
# Ready the test input script
# Processing 57/2124
# Ready the test input script
# Processing 58/2124
# Ready the test input script
# Processing 59/2124
# Ready the test input script
# Processing 60/2124
# Ready the test input script
# Processing 61/2124
# Ready the test input script
# Processing 62/2124
# Ready the test input script
# Processing 63/2124
# Ready the test input script
# Processing 64/2124
# Ready the test input script
# Processing 65/2124
# Ready the test input script
# Processing 66/2124
# Ready the test input script
# Processing 67/2124
# Ready the test input script
# Processing 68/2124
# Ready the test input script
# Processing 69/2124
# Ready the test input script
# Processing 70/2124
# Ready the test input script
# Processing 71/2124
# Ready the test input script
# Processing 72/2124
# Ready the test input script
# Processing 73/2124
# Ready the test input script
# Processing 74/2124
# Ready the test input script
# Processing 75/2124
# Ready the test input script
# Processing 76/2124
# Ready the test input script
# Processing 77/2124
# Ready the test input script
# Processing 78/2124
# Ready the test input script
# Processing 79/2124
# Ready the test input script
# Processing 80/2124
# Ready the test input script
# Processing 81/2124
# Ready the test input script
# Processing 82/2124
# Ready the test input script
# Processing 83/2124
# Ready the test input script
# Processing 84/2124
# Ready the test input script
# Processing 85/2124
# Ready the test input script
# Processing 86/2124
# Ready the test input script
# Processing 87/2124
# Ready the test input script
# Processing 88/2124
# Ready the test input script
# Processing 89/2124
# Ready the test input script
# Processing 90/2124
# Ready the test input script
# Processing 91/2124
# Ready the test input script
# Processing 92/2124
# Ready the test input script
# Processing 93/2124
# Ready the test input script
# Processing 94/2124
# Ready the test input script
# Processing 95/2124
# Ready the test input script
# Processing 96/2124
# Ready the test input script
# Processing 97/2124
# Ready the test input script
# Processing 98/2124
# Ready the test input script
# Processing 99/2124
# Ready the test input script
# Processing 100/2124
# Ready the test input script
# Processing 101/2124
# Ready the test input script
# Processing 102/2124
# Ready the test input script
# Processing 103/2124
# Ready the test input script
# Processing 104/2124
# Ready the test input script
# Processing 105/2124
# Ready the test input script
# Processing 106/2124
# Ready the test input script
# Processing 107/2124
# Ready the test input script
# Processing 108/2124
# Ready the test input script
# Processing 109/2124
# Ready the test input script
# Processing 110/2124
# Ready the test input script
# Processing 111/2124
# Ready the test input script
# Processing 112/2124
# Ready the test input script
# Processing 113/2124
# Ready the test input script
# Processing 114/2124
# Ready the test input script
# Processing 115/2124
# Ready the test input script
# Processing 116/2124
# Ready the test input script
# Processing 117/2124
# Ready the test input script
# Processing 118/2124
# Ready the test input script
# Processing 119/2124
# Ready the test input script
# Processing 120/2124
# Ready the test input script
# Processing 121/2124
# Ready the test input script
# Processing 122/2124
# Ready the test input script
# Processing 123/2124
# Ready the test input script
# Processing 124/2124
# Ready the test input script
# Processing 125/2124
# Ready the test input script
# Processing 126/2124
# Ready the test input script
# Processing 127/2124
# Ready the test input script
# Processing 128/2124
# Ready the test input script
# Processing 129/2124
# Ready the test input script
# Processing 130/2124
# Ready the test input script
# Processing 131/2124
# Ready the test input script
# Processing 132/2124
# Ready the test input script
# Processing 133/2124
# Ready the test input script
# Processing 134/2124
# Ready the test input script
# Processing 135/2124
# Ready the test input script
# Processing 136/2124
# Ready the test input script
# Processing 137/2124
# Ready the test input script
# Processing 138/2124
# Ready the test input script
# Processing 139/2124
# Ready the test input script
# Processing 140/2124
# Ready the test input script
# Processing 141/2124
# Ready the test input script
# Processing 142/2124
# Ready the test input script
# Processing 143/2124
# Ready the test input script
# Processing 144/2124
# Ready the test input script
# Processing 145/2124
# Ready the test input script
# Processing 146/2124
# Ready the test input script
# Processing 147/2124
# Ready the test input script
# Processing 148/2124
# Ready the test input script
# Processing 149/2124
# Ready the test input script
# Processing 150/2124
# Ready the test input script
# Processing 151/2124
# Ready the test input script
# Processing 152/2124
# Ready the test input script
# Processing 153/2124
# Ready the test input script
# Processing 154/2124
# Ready the test input script
# Processing 155/2124
# Ready the test input script
# Processing 156/2124
# Ready the test input script
# Processing 157/2124
# Ready the test input script
# Processing 158/2124
# Ready the test input script
# Processing 159/2124
# Ready the test input script
# Processing 160/2124
# Ready the test input script
# Processing 161/2124
# Ready the test input script
# Processing 162/2124
# Ready the test input script
# Processing 163/2124
# Ready the test input script
# Processing 164/2124
# Ready the test input script
# Processing 165/2124
# Ready the test input script
# Processing 166/2124
# Ready the test input script
# Processing 167/2124
# Ready the test input script
# Processing 168/2124
# Ready the test input script
# Processing 169/2124
# Ready the test input script
# Processing 170/2124
# Ready the test input script
# Processing 171/2124
# Ready the test input script
# Processing 172/2124
# Ready the test input script
# Processing 173/2124
# Ready the test input script
# Processing 174/2124
# Ready the test input script
# Processing 175/2124
# Ready the test input script
# Processing 176/2124
# Ready the test input script
# Processing 177/2124
# Ready the test input script
# Processing 178/2124
# Ready the test input script
# Processing 179/2124
# Ready the test input script
# Processing 180/2124
# Ready the test input script
# Processing 181/2124
# Ready the test input script
# Processing 182/2124
# Ready the test input script
# Processing 183/2124
# Ready the test input script
# Processing 184/2124
# Ready the test input script
# Processing 185/2124
# Ready the test input script
# Processing 186/2124
# Ready the test input script
# Processing 187/2124
# Ready the test input script
# Processing 188/2124
# Ready the test input script
# Processing 189/2124
# Ready the test input script
# Processing 190/2124
# Ready the test input script
# Processing 191/2124
# Ready the test input script
# Processing 192/2124
# Ready the test input script
# Processing 193/2124
# Ready the test input script
# Processing 194/2124
# Ready the test input script
# Processing 195/2124
# Ready the test input script
# Processing 196/2124
# Ready the test input script
# Processing 197/2124
# Ready the test input script
# Processing 198/2124
# Ready the test input script
# Processing 199/2124
# Ready the test input script
# Processing 200/2124
# Ready the test input script
# Processing 201/2124
# Ready the test input script
# Processing 202/2124
# Ready the test input script
# Processing 203/2124
# Ready the test input script
# Processing 204/2124
# Ready the test input script
# Processing 205/2124
# Ready the test input script
# Processing 206/2124
# Ready the test input script
# Processing 207/2124
# Ready the test input script
# Processing 208/2124
# Ready the test input script
# Processing 209/2124
# Ready the test input script
# Processing 210/2124
# Ready the test input script
# Processing 211/2124
# Ready the test input script
# Processing 212/2124
# Ready the test input script
# Processing 213/2124
# Ready the test input script
# Processing 214/2124
# Ready the test input script
# Processing 215/2124
# Ready the test input script
# Processing 216/2124
# Ready the test input script
# Processing 217/2124
# Ready the test input script
# Processing 218/2124
# Ready the test input script
# Processing 219/2124
# Ready the test input script
# Processing 220/2124
# Ready the test input script
# Processing 221/2124
# Ready the test input script
# Processing 222/2124
# Ready the test input script
# Processing 223/2124
# Ready the test input script
# Processing 224/2124
# Ready the test input script
# Processing 225/2124
# Ready the test input script
# Processing 226/2124
# Ready the test input script
# Processing 227/2124
# Ready the test input script
# Processing 228/2124
# Ready the test input script
# Processing 229/2124
# Ready the test input script
# Processing 230/2124
# Ready the test input script
# Processing 231/2124
# Ready the test input script
# Processing 232/2124
# Ready the test input script
# Processing 233/2124
# Ready the test input script
# Processing 234/2124
# Ready the test input script
# Processing 235/2124
# Ready the test input script
# Processing 236/2124
# Ready the test input script
# Processing 237/2124
# Ready the test input script
# Processing 238/2124
# Ready the test input script
# Processing 239/2124
# Ready the test input script
# Processing 240/2124
# Ready the test input script
# Processing 241/2124
# Ready the test input script
# Processing 242/2124
# Ready the test input script
# Processing 243/2124
# Ready the test input script
# Processing 244/2124
# Ready the test input script
# Processing 245/2124
# Ready the test input script
# Processing 246/2124
# Ready the test input script
# Processing 247/2124
# Ready the test input script
# Processing 248/2124
# Ready the test input script
# Processing 249/2124
# Ready the test input script
# Processing 250/2124
# Ready the test input script
# Processing 251/2124
# Ready the test input script
# Processing 252/2124
# Ready the test input script
# Processing 253/2124
# Ready the test input script
# Processing 254/2124
# Ready the test input script
# Processing 255/2124
# Ready the test input script
# Processing 256/2124
# Ready the test input script
# Processing 257/2124
# Ready the test input script
# Processing 258/2124
# Ready the test input script
# Processing 259/2124
# Ready the test input script
# Processing 260/2124
# Ready the test input script
# Processing 261/2124
# Ready the test input script
# Processing 262/2124
# Ready the test input script
# Processing 263/2124
# Ready the test input script
# Processing 264/2124
# Ready the test input script
# Processing 265/2124
# Ready the test input script
# Processing 266/2124
# Ready the test input script
# Processing 267/2124
# Ready the test input script
# Processing 268/2124
# Ready the test input script
# Processing 269/2124
# Ready the test input script
# Processing 270/2124
# Ready the test input script
# Processing 271/2124
# Ready the test input script
# Processing 272/2124
# Ready the test input script
# Processing 273/2124
# Ready the test input script
# Processing 274/2124
# Ready the test input script
# Processing 275/2124
# Ready the test input script
# Processing 276/2124
# Ready the test input script
# Processing 277/2124
# Ready the test input script
# Processing 278/2124
# Ready the test input script
# Processing 279/2124
# Ready the test input script
# Processing 280/2124
# Ready the test input script
# Processing 281/2124
# Ready the test input script
# Processing 282/2124
# Ready the test input script
# Processing 283/2124
# Ready the test input script
# Processing 284/2124
# Ready the test input script
# Processing 285/2124
# Ready the test input script
# Processing 286/2124
# Ready the test input script
# Processing 287/2124
# Ready the test input script
# Processing 288/2124
# Ready the test input script
# Processing 289/2124
# Ready the test input script
# Processing 290/2124
# Ready the test input script
# Processing 291/2124
# Ready the test input script
# Processing 292/2124
# Ready the test input script
# Processing 293/2124
# Ready the test input script
# Processing 294/2124
# Ready the test input script
# Processing 295/2124
# Ready the test input script
# Processing 296/2124
# Ready the test input script
# Processing 297/2124
# Ready the test input script
# Processing 298/2124
# Ready the test input script
# Processing 299/2124
# Ready the test input script
# Processing 300/2124
# Ready the test input script
# Processing 301/2124
# Ready the test input script
# Processing 302/2124
# Ready the test input script
# Processing 303/2124
# Ready the test input script
# Processing 304/2124
# Ready the test input script
# Processing 305/2124
# Ready the test input script
# Processing 306/2124
# Ready the test input script
# Processing 307/2124
# Ready the test input script
# Processing 308/2124
# Ready the test input script
# Processing 309/2124
# Ready the test input script
# Processing 310/2124
# Ready the test input script
# Processing 311/2124
# Ready the test input script
# Processing 312/2124
# Ready the test input script
# Processing 313/2124
# Ready the test input script
# Processing 314/2124
# Ready the test input script
# Processing 315/2124
# Ready the test input script
# Processing 316/2124
# Ready the test input script
# Processing 317/2124
# Ready the test input script
# Processing 318/2124
# Ready the test input script
# Processing 319/2124
# Ready the test input script
# Processing 320/2124
# Ready the test input script
# Processing 321/2124
# Ready the test input script
# Processing 322/2124
# Ready the test input script
# Processing 323/2124
# Ready the test input script
# Processing 324/2124
# Ready the test input script
# Processing 325/2124
# Ready the test input script
# Processing 326/2124
# Ready the test input script
# Processing 327/2124
# Ready the test input script
# Processing 328/2124
# Ready the test input script
# Processing 329/2124
# Ready the test input script
# Processing 330/2124
# Ready the test input script
# Processing 331/2124
# Ready the test input script
# Processing 332/2124
# Ready the test input script
# Processing 333/2124
# Ready the test input script
# Processing 334/2124
# Ready the test input script
# Processing 335/2124
# Ready the test input script
# Processing 336/2124
# Ready the test input script
# Processing 337/2124
# Ready the test input script
# Processing 338/2124
# Ready the test input script
# Processing 339/2124
# Ready the test input script
# Processing 340/2124
# Ready the test input script
# Processing 341/2124
# Ready the test input script
# Processing 342/2124
# Ready the test input script
# Processing 343/2124
# Ready the test input script
# Processing 344/2124
# Ready the test input script
# Processing 345/2124
# Ready the test input script
# Processing 346/2124
# Ready the test input script
# Processing 347/2124
# Ready the test input script
# Processing 348/2124
# Ready the test input script
# Processing 349/2124
# Ready the test input script
# Processing 350/2124
# Ready the test input script
# Processing 351/2124
# Ready the test input script
# Processing 352/2124
# Ready the test input script
# Processing 353/2124
# Ready the test input script
# Processing 354/2124
# Ready the test input script
# Processing 355/2124
# Ready the test input script
# Processing 356/2124
# Ready the test input script
# Processing 357/2124
# Ready the test input script
# Processing 358/2124
# Ready the test input script
# Processing 359/2124
# Ready the test input script
# Processing 360/2124
# Ready the test input script
# Processing 361/2124
# Ready the test input script
# Processing 362/2124
# Ready the test input script
# Processing 363/2124
# Ready the test input script
# Processing 364/2124
# Ready the test input script
# Processing 365/2124
# Ready the test input script
# Processing 366/2124
# Ready the test input script
# Processing 367/2124
# Ready the test input script
# Processing 368/2124
# Ready the test input script
# Processing 369/2124
# Ready the test input script
# Processing 370/2124
# Ready the test input script
# Processing 371/2124
# Ready the test input script
# Processing 372/2124
# Ready the test input script
# Processing 373/2124
# Ready the test input script
# Processing 374/2124
# Ready the test input script
# Processing 375/2124
# Ready the test input script
# Processing 376/2124
# Ready the test input script
# Processing 377/2124
# Ready the test input script
# Processing 378/2124
# Ready the test input script
# Processing 379/2124
# Ready the test input script
# Processing 380/2124
# Ready the test input script
# Processing 381/2124
# Ready the test input script
# Processing 382/2124
# Ready the test input script
# Processing 383/2124
# Ready the test input script
# Processing 384/2124
# Ready the test input script
# Processing 385/2124
# Ready the test input script
# Processing 386/2124
# Ready the test input script
# Processing 387/2124
# Ready the test input script
# Processing 388/2124
# Ready the test input script
# Processing 389/2124
# Ready the test input script
# Processing 390/2124
# Ready the test input script
# Processing 391/2124
# Ready the test input script
# Processing 392/2124
# Ready the test input script
# Processing 393/2124
# Ready the test input script
# Processing 394/2124
# Ready the test input script
# Processing 395/2124
# Ready the test input script
# Processing 396/2124
# Ready the test input script
# Processing 397/2124
# Ready the test input script
# Processing 398/2124
# Ready the test input script
# Processing 399/2124
# Ready the test input script
# Processing 400/2124
# Ready the test input script
# Processing 401/2124
# Ready the test input script
# Processing 402/2124
# Ready the test input script
# Processing 403/2124
# Ready the test input script
# Processing 404/2124
# Ready the test input script
# Processing 405/2124
# Ready the test input script
# Processing 406/2124
# Ready the test input script
# Processing 407/2124
# Ready the test input script
# Processing 408/2124
# Ready the test input script
# Processing 409/2124
# Ready the test input script
# Processing 410/2124
# Ready the test input script
# Processing 411/2124
# Ready the test input script
# Processing 412/2124
# Ready the test input script
# Processing 413/2124
# Ready the test input script
# Processing 414/2124
# Ready the test input script
# Processing 415/2124
# Ready the test input script
# Processing 416/2124
# Ready the test input script
# Processing 417/2124
# Ready the test input script
# Processing 418/2124
# Ready the test input script
# Processing 419/2124
# Ready the test input script
# Processing 420/2124
# Ready the test input script
# Processing 421/2124
# Ready the test input script
# Processing 422/2124
# Ready the test input script
# Processing 423/2124
# Ready the test input script
# Processing 424/2124
# Ready the test input script
# Processing 425/2124
# Ready the test input script
# Processing 426/2124
# Ready the test input script
# Processing 427/2124
# Ready the test input script
# Processing 428/2124
# Ready the test input script
# Processing 429/2124
# Ready the test input script
# Processing 430/2124
# Ready the test input script
# Processing 431/2124
# Ready the test input script
# Processing 432/2124
# Ready the test input script
# Processing 433/2124
# Ready the test input script
# Processing 434/2124
# Ready the test input script
# Processing 435/2124
# Ready the test input script
# Processing 436/2124
# Ready the test input script
# Processing 437/2124
# Ready the test input script
# Processing 438/2124
# Ready the test input script
# Processing 439/2124
# Ready the test input script
# Processing 440/2124
# Ready the test input script
# Processing 441/2124
# Ready the test input script
# Processing 442/2124
# Ready the test input script
# Processing 443/2124
# Ready the test input script
# Processing 444/2124
# Ready the test input script
# Processing 445/2124
# Ready the test input script
# Processing 446/2124
# Ready the test input script
# Processing 447/2124
# Ready the test input script
# Processing 448/2124
# Ready the test input script
# Processing 449/2124
# Ready the test input script
# Processing 450/2124
# Ready the test input script
# Processing 451/2124
# Ready the test input script
# Processing 452/2124
# Ready the test input script
# Processing 453/2124
# Ready the test input script
# Processing 454/2124
# Ready the test input script
# Processing 455/2124
# Ready the test input script
# Processing 456/2124
# Ready the test input script
# Processing 457/2124
# Ready the test input script
# Processing 458/2124
# Ready the test input script
# Processing 459/2124
# Ready the test input script
# Processing 460/2124
# Ready the test input script
# Processing 461/2124
# Ready the test input script
# Processing 462/2124
# Ready the test input script
# Processing 463/2124
# Ready the test input script
# Processing 464/2124
# Ready the test input script
# Processing 465/2124
# Ready the test input script
# Processing 466/2124
# Ready the test input script
# Processing 467/2124
# Ready the test input script
# Processing 468/2124
# Ready the test input script
# Processing 469/2124
# Ready the test input script
# Processing 470/2124
# Ready the test input script
# Processing 471/2124
# Ready the test input script
# Processing 472/2124
# Ready the test input script
# Processing 473/2124
# Ready the test input script
# Processing 474/2124
# Ready the test input script
# Processing 475/2124
# Ready the test input script
# Processing 476/2124
# Ready the test input script
# Processing 477/2124
# Ready the test input script
# Processing 478/2124
# Ready the test input script
# Processing 479/2124
# Ready the test input script
# Processing 480/2124
# Ready the test input script
# Processing 481/2124
# Ready the test input script
# Processing 482/2124
# Ready the test input script
# Processing 483/2124
# Ready the test input script
# Processing 484/2124
# Ready the test input script
# Processing 485/2124
# Ready the test input script
# Processing 486/2124
# Ready the test input script
# Processing 487/2124
# Ready the test input script
# Processing 488/2124
# Ready the test input script
# Processing 489/2124
# Ready the test input script
# Processing 490/2124
# Ready the test input script
# Processing 491/2124
# Ready the test input script
# Processing 492/2124
# Ready the test input script
# Processing 493/2124
# Ready the test input script
# Processing 494/2124
# Ready the test input script
# Processing 495/2124
# Ready the test input script
# Processing 496/2124
# Ready the test input script
# Processing 497/2124
# Ready the test input script
# Processing 498/2124
# Ready the test input script
# Processing 499/2124
# Ready the test input script
# Processing 500/2124
# Ready the test input script
# Processing 501/2124
# Ready the test input script
# Processing 502/2124
# Ready the test input script
# Processing 503/2124
# Ready the test input script
# Processing 504/2124
# Ready the test input script
# Processing 505/2124
# Ready the test input script
# Processing 506/2124
# Ready the test input script
# Processing 507/2124
# Ready the test input script
# Processing 508/2124
# Ready the test input script
# Processing 509/2124
# Ready the test input script
# Processing 510/2124
# Ready the test input script
# Processing 511/2124
# Ready the test input script
# Processing 512/2124
# Ready the test input script
# Processing 513/2124
# Ready the test input script
# Processing 514/2124
# Ready the test input script
# Processing 515/2124
# Ready the test input script
# Processing 516/2124
# Ready the test input script
# Processing 517/2124
# Ready the test input script
# Processing 518/2124
# Ready the test input script
# Processing 519/2124
# Ready the test input script
# Processing 520/2124
# Ready the test input script
# Processing 521/2124
# Ready the test input script
# Processing 522/2124
# Ready the test input script
# Processing 523/2124
# Ready the test input script
# Processing 524/2124
# Ready the test input script
# Processing 525/2124
# Ready the test input script
# Processing 526/2124
# Ready the test input script
# Processing 527/2124
# Ready the test input script
# Processing 528/2124
# Ready the test input script
# Processing 529/2124
# Ready the test input script
# Processing 530/2124
# Ready the test input script
# Processing 531/2124
# Ready the test input script
# Processing 532/2124
# Ready the test input script
# Processing 533/2124
# Ready the test input script
# Processing 534/2124
# Ready the test input script
# Processing 535/2124
# Ready the test input script
# Processing 536/2124
# Ready the test input script
# Processing 537/2124
# Ready the test input script
# Processing 538/2124
# Ready the test input script
# Processing 539/2124
# Ready the test input script
# Processing 540/2124
# Ready the test input script
# Processing 541/2124
# Ready the test input script
# Processing 542/2124
# Ready the test input script
# Processing 543/2124
# Ready the test input script
# Processing 544/2124
# Ready the test input script
# Processing 545/2124
# Ready the test input script
# Processing 546/2124
# Ready the test input script
# Processing 547/2124
# Ready the test input script
# Processing 548/2124
# Ready the test input script
# Processing 549/2124
# Ready the test input script
# Processing 550/2124
# Ready the test input script
# Processing 551/2124
# Ready the test input script
# Processing 552/2124
# Ready the test input script
# Processing 553/2124
# Ready the test input script
# Processing 554/2124
# Ready the test input script
# Processing 555/2124
# Ready the test input script
# Processing 556/2124
# Ready the test input script
# Processing 557/2124
# Ready the test input script
# Processing 558/2124
# Ready the test input script
# Processing 559/2124
# Ready the test input script
# Processing 560/2124
# Ready the test input script
# Processing 561/2124
# Ready the test input script
# Processing 562/2124
# Ready the test input script
# Processing 563/2124
# Ready the test input script
# Processing 564/2124
# Ready the test input script
# Processing 565/2124
# Ready the test input script
# Processing 566/2124
# Ready the test input script
# Processing 567/2124
# Ready the test input script
# Processing 568/2124
# Ready the test input script
# Processing 569/2124
# Ready the test input script
# Processing 570/2124
# Ready the test input script
# Processing 571/2124
# Ready the test input script
# Processing 572/2124
# Ready the test input script
# Processing 573/2124
# Ready the test input script
# Processing 574/2124
# Ready the test input script
# Processing 575/2124
# Ready the test input script
# Processing 576/2124
# Ready the test input script
# Processing 577/2124
# Ready the test input script
# Processing 578/2124
# Ready the test input script
# Processing 579/2124
# Ready the test input script
# Processing 580/2124
# Ready the test input script
# Processing 581/2124
# Ready the test input script
# Processing 582/2124
# Ready the test input script
# Processing 583/2124
# Ready the test input script
# Processing 584/2124
# Ready the test input script
# Processing 585/2124
# Ready the test input script
# Processing 586/2124
# Ready the test input script
# Processing 587/2124
# Ready the test input script
# Processing 588/2124
# Ready the test input script
# Processing 589/2124
# Ready the test input script
# Processing 590/2124
# Ready the test input script
# Processing 591/2124
# Ready the test input script
# Processing 592/2124
# Ready the test input script
# Processing 593/2124
# Ready the test input script
# Processing 594/2124
# Ready the test input script
# Processing 595/2124
# Ready the test input script
# Processing 596/2124
# Ready the test input script
# Processing 597/2124
# Ready the test input script
# Processing 598/2124
# Ready the test input script
# Processing 599/2124
# Ready the test input script
# Processing 600/2124
# Ready the test input script
# Processing 601/2124
# Ready the test input script
# Processing 602/2124
# Ready the test input script
# Processing 603/2124
# Ready the test input script
# Processing 604/2124
# Ready the test input script
# Processing 605/2124
# Ready the test input script
# Processing 606/2124
# Ready the test input script
# Processing 607/2124
# Ready the test input script
# Processing 608/2124
# Ready the test input script
# Processing 609/2124
# Ready the test input script
# Processing 610/2124
# Ready the test input script
# Processing 611/2124
# Ready the test input script
# Processing 612/2124
# Ready the test input script
# Processing 613/2124
# Ready the test input script
# Processing 614/2124
# Ready the test input script
# Processing 615/2124
# Ready the test input script
# Processing 616/2124
# Ready the test input script
# Processing 617/2124
# Ready the test input script
# Processing 618/2124
# Ready the test input script
# Processing 619/2124
# Ready the test input script
# Processing 620/2124
# Ready the test input script
# Processing 621/2124
# Ready the test input script
# Processing 622/2124
# Ready the test input script
# Processing 623/2124
# Ready the test input script
# Processing 624/2124
# Ready the test input script
# Processing 625/2124
# Ready the test input script
# Processing 626/2124
# Ready the test input script
# Processing 627/2124
# Ready the test input script
# Processing 628/2124
# Ready the test input script
# Processing 629/2124
# Ready the test input script
# Processing 630/2124
# Ready the test input script
# Processing 631/2124
# Ready the test input script
# Processing 632/2124
# Ready the test input script
# Processing 633/2124
# Ready the test input script
# Processing 634/2124
# Ready the test input script
# Processing 635/2124
# Ready the test input script
# Processing 636/2124
# Ready the test input script
# Processing 637/2124
# Ready the test input script
# Processing 638/2124
# Ready the test input script
# Processing 639/2124
# Ready the test input script
# Processing 640/2124
# Ready the test input script
# Processing 641/2124
# Ready the test input script
# Processing 642/2124
# Ready the test input script
# Processing 643/2124
# Ready the test input script
# Processing 644/2124
# Ready the test input script
# Processing 645/2124
# Ready the test input script
# Processing 646/2124
# Ready the test input script
# Processing 647/2124
# Ready the test input script
# Processing 648/2124
# Ready the test input script
# Processing 649/2124
# Ready the test input script
# Processing 650/2124
# Ready the test input script
# Processing 651/2124
# Ready the test input script
# Processing 652/2124
# Ready the test input script
# Processing 653/2124
# Ready the test input script
# Processing 654/2124
# Ready the test input script
# Processing 655/2124
# Ready the test input script
# Processing 656/2124
# Ready the test input script
# Processing 657/2124
# Ready the test input script
# Processing 658/2124
# Ready the test input script
# Processing 659/2124
# Ready the test input script
# Processing 660/2124
# Ready the test input script
# Processing 661/2124
# Ready the test input script
# Processing 662/2124
# Ready the test input script
# Processing 663/2124
# Ready the test input script
# Processing 664/2124
# Ready the test input script
# Processing 665/2124
# Ready the test input script
# Processing 666/2124
# Ready the test input script
# Processing 667/2124
# Ready the test input script
# Processing 668/2124
# Ready the test input script
# Processing 669/2124
# Ready the test input script
# Processing 670/2124
# Ready the test input script
# Processing 671/2124
# Ready the test input script
# Processing 672/2124
# Ready the test input script
# Processing 673/2124
# Ready the test input script
# Processing 674/2124
# Ready the test input script
# Processing 675/2124
# Ready the test input script
# Processing 676/2124
# Ready the test input script
# Processing 677/2124
# Ready the test input script
# Processing 678/2124
# Ready the test input script
# Processing 679/2124
# Ready the test input script
# Processing 680/2124
# Ready the test input script
# Processing 681/2124
# Ready the test input script
# Processing 682/2124
# Ready the test input script
# Processing 683/2124
# Ready the test input script
# Processing 684/2124
# Ready the test input script
# Processing 685/2124
# Ready the test input script
# Processing 686/2124
# Ready the test input script
# Processing 687/2124
# Ready the test input script
# Processing 688/2124
# Ready the test input script
# Processing 689/2124
# Ready the test input script
# Processing 690/2124
# Ready the test input script
# Processing 691/2124
# Ready the test input script
# Processing 692/2124
# Ready the test input script
# Processing 693/2124
# Ready the test input script
# Processing 694/2124
# Ready the test input script
# Processing 695/2124
# Ready the test input script
# Processing 696/2124
# Ready the test input script
# Processing 697/2124
# Ready the test input script
# Processing 698/2124
# Ready the test input script
# Processing 699/2124
# Ready the test input script
# Processing 700/2124
# Ready the test input script
# Processing 701/2124
# Ready the test input script
# Processing 702/2124
# Ready the test input script
# Processing 703/2124
# Ready the test input script
# Processing 704/2124
# Ready the test input script
# Processing 705/2124
# Ready the test input script
# Processing 706/2124
# Ready the test input script
# Processing 707/2124
# Ready the test input script
# Processing 708/2124
# Ready the test input script
# Processing 709/2124
# Ready the test input script
# Processing 710/2124
# Ready the test input script
# Processing 711/2124
# Ready the test input script
# Processing 712/2124
# Ready the test input script
# Processing 713/2124
# Ready the test input script
# Processing 714/2124
# Ready the test input script
# Processing 715/2124
# Ready the test input script
# Processing 716/2124
# Ready the test input script
# Processing 717/2124
# Ready the test input script
# Processing 718/2124
# Ready the test input script
# Processing 719/2124
# Ready the test input script
# Processing 720/2124
# Ready the test input script
# Processing 721/2124
# Ready the test input script
# Processing 722/2124
# Ready the test input script
# Processing 723/2124
# Ready the test input script
# Processing 724/2124
# Ready the test input script
# Processing 725/2124
# Ready the test input script
# Processing 726/2124
# Ready the test input script
# Processing 727/2124
# Ready the test input script
# Processing 728/2124
# Ready the test input script
# Processing 729/2124
# Ready the test input script
# Processing 730/2124
# Ready the test input script
# Processing 731/2124
# Ready the test input script
# Processing 732/2124
# Ready the test input script
# Processing 733/2124
# Ready the test input script
# Processing 734/2124
# Ready the test input script
# Processing 735/2124
# Ready the test input script
# Processing 736/2124
# Ready the test input script
# Processing 737/2124
# Ready the test input script
# Processing 738/2124
# Ready the test input script
# Processing 739/2124
# Ready the test input script
# Processing 740/2124
# Ready the test input script
# Processing 741/2124
# Ready the test input script
# Processing 742/2124
# Ready the test input script
# Processing 743/2124
# Ready the test input script
# Processing 744/2124
# Ready the test input script
# Processing 745/2124
# Ready the test input script
# Processing 746/2124
# Ready the test input script
# Processing 747/2124
# Ready the test input script
# Processing 748/2124
# Ready the test input script
# Processing 749/2124
# Ready the test input script
# Processing 750/2124
# Ready the test input script
# Processing 751/2124
# Ready the test input script
# Processing 752/2124
# Ready the test input script
# Processing 753/2124
# Ready the test input script
# Processing 754/2124
# Ready the test input script
# Processing 755/2124
# Ready the test input script
# Processing 756/2124
# Ready the test input script
# Processing 757/2124
# Ready the test input script
# Processing 758/2124
# Ready the test input script
# Processing 759/2124
# Ready the test input script
# Processing 760/2124
# Ready the test input script
# Processing 761/2124
# Ready the test input script
# Processing 762/2124
# Ready the test input script
# Processing 763/2124
# Ready the test input script
# Processing 764/2124
# Ready the test input script
# Processing 765/2124
# Ready the test input script
# Processing 766/2124
# Ready the test input script
# Processing 767/2124
# Ready the test input script
# Processing 768/2124
# Ready the test input script
# Processing 769/2124
# Ready the test input script
# Processing 770/2124
# Ready the test input script
# Processing 771/2124
# Ready the test input script
# Processing 772/2124
# Ready the test input script
# Processing 773/2124
# Ready the test input script
# Processing 774/2124
# Ready the test input script
# Processing 775/2124
# Ready the test input script
# Processing 776/2124
# Ready the test input script
# Processing 777/2124
# Ready the test input script
# Processing 778/2124
# Ready the test input script
# Processing 779/2124
# Ready the test input script
# Processing 780/2124
# Ready the test input script
# Processing 781/2124
# Ready the test input script
# Processing 782/2124
# Ready the test input script
# Processing 783/2124
# Ready the test input script
# Processing 784/2124
# Ready the test input script
# Processing 785/2124
# Ready the test input script
# Processing 786/2124
# Ready the test input script
# Processing 787/2124
# Ready the test input script
# Processing 788/2124
# Ready the test input script
# Processing 789/2124
# Ready the test input script
# Processing 790/2124
# Ready the test input script
# Processing 791/2124
# Ready the test input script
# Processing 792/2124
# Ready the test input script
# Processing 793/2124
# Ready the test input script
# Processing 794/2124
# Ready the test input script
# Processing 795/2124
# Ready the test input script
# Processing 796/2124
# Ready the test input script
# Processing 797/2124
# Ready the test input script
# Processing 798/2124
# Ready the test input script
# Processing 799/2124
# Ready the test input script
# Processing 800/2124
# Ready the test input script
# Processing 801/2124
# Ready the test input script
# Processing 802/2124
# Ready the test input script
# Processing 803/2124
# Ready the test input script
# Processing 804/2124
# Ready the test input script
# Processing 805/2124
# Ready the test input script
# Processing 806/2124
# Ready the test input script
# Processing 807/2124
# Ready the test input script
# Processing 808/2124
# Ready the test input script
# Processing 809/2124
# Ready the test input script
# Processing 810/2124
# Ready the test input script
# Processing 811/2124
# Ready the test input script
# Processing 812/2124
# Ready the test input script
# Processing 813/2124
# Ready the test input script
# Processing 814/2124
# Ready the test input script
# Processing 815/2124
# Ready the test input script
# Processing 816/2124
# Ready the test input script
# Processing 817/2124
# Ready the test input script
# Processing 818/2124
# Ready the test input script
# Processing 819/2124
# Ready the test input script
# Processing 820/2124
# Ready the test input script
# Processing 821/2124
# Ready the test input script
# Processing 822/2124
# Ready the test input script
# Processing 823/2124
# Ready the test input script
# Processing 824/2124
# Ready the test input script
# Processing 825/2124
# Ready the test input script
# Processing 826/2124
# Ready the test input script
# Processing 827/2124
# Ready the test input script
# Processing 828/2124
# Ready the test input script
# Processing 829/2124
# Ready the test input script
# Processing 830/2124
# Ready the test input script
# Processing 831/2124
# Ready the test input script
# Processing 832/2124
# Ready the test input script
# Processing 833/2124
# Ready the test input script
# Processing 834/2124
# Ready the test input script
# Processing 835/2124
# Ready the test input script
# Processing 836/2124
# Ready the test input script
# Processing 837/2124
# Ready the test input script
# Processing 838/2124
# Ready the test input script
# Processing 839/2124
# Ready the test input script
# Processing 840/2124
# Ready the test input script
# Processing 841/2124
# Ready the test input script
# Processing 842/2124
# Ready the test input script
# Processing 843/2124
# Ready the test input script
# Processing 844/2124
# Ready the test input script
# Processing 845/2124
# Ready the test input script
# Processing 846/2124
# Ready the test input script
# Processing 847/2124
# Ready the test input script
# Processing 848/2124
# Ready the test input script
# Processing 849/2124
# Ready the test input script
# Processing 850/2124
# Ready the test input script
# Processing 851/2124
# Ready the test input script
# Processing 852/2124
# Ready the test input script
# Processing 853/2124
# Ready the test input script
# Processing 854/2124
# Ready the test input script
# Processing 855/2124
# Ready the test input script
# Processing 856/2124
# Ready the test input script
# Processing 857/2124
# Ready the test input script
# Processing 858/2124
# Ready the test input script
# Processing 859/2124
# Ready the test input script
# Processing 860/2124
# Ready the test input script
# Processing 861/2124
# Ready the test input script
# Processing 862/2124
# Ready the test input script
# Processing 863/2124
# Ready the test input script
# Processing 864/2124
# Ready the test input script
# Processing 865/2124
# Ready the test input script
# Processing 866/2124
# Ready the test input script
# Processing 867/2124
# Ready the test input script
# Processing 868/2124
# Ready the test input script
# Processing 869/2124
# Ready the test input script
# Processing 870/2124
# Ready the test input script
# Processing 871/2124
# Ready the test input script
# Processing 872/2124
# Ready the test input script
# Processing 873/2124
# Ready the test input script
# Processing 874/2124
# Ready the test input script
# Processing 875/2124
# Ready the test input script
# Processing 876/2124
# Ready the test input script
# Processing 877/2124
# Ready the test input script
# Processing 878/2124
# Ready the test input script
# Processing 879/2124
# Ready the test input script
# Processing 880/2124
# Ready the test input script
# Processing 881/2124
# Ready the test input script
# Processing 882/2124
# Ready the test input script
# Processing 883/2124
# Ready the test input script
# Processing 884/2124
# Ready the test input script
# Processing 885/2124
# Ready the test input script
# Processing 886/2124
# Ready the test input script
# Processing 887/2124
# Ready the test input script
# Processing 888/2124
# Ready the test input script
# Processing 889/2124
# Ready the test input script
# Processing 890/2124
# Ready the test input script
# Processing 891/2124
# Ready the test input script
# Processing 892/2124
# Ready the test input script
# Processing 893/2124
# Ready the test input script
# Processing 894/2124
# Ready the test input script
# Processing 895/2124
# Ready the test input script
# Processing 896/2124
# Ready the test input script
# Processing 897/2124
# Ready the test input script
# Processing 898/2124
# Ready the test input script
# Processing 899/2124
# Ready the test input script
# Processing 900/2124
# Ready the test input script
# Processing 901/2124
# Ready the test input script
# Processing 902/2124
# Ready the test input script
# Processing 903/2124
# Ready the test input script
# Processing 904/2124
# Ready the test input script
# Processing 905/2124
# Ready the test input script
# Processing 906/2124
# Ready the test input script
# Processing 907/2124
# Ready the test input script
# Processing 908/2124
# Ready the test input script
# Processing 909/2124
# Ready the test input script
# Processing 910/2124
# Ready the test input script
# Processing 911/2124
# Ready the test input script
# Processing 912/2124
# Ready the test input script
# Processing 913/2124
# Ready the test input script
# Processing 914/2124
# Ready the test input script
# Processing 915/2124
# Ready the test input script
# Processing 916/2124
# Ready the test input script
# Processing 917/2124
# Ready the test input script
# Processing 918/2124
# Ready the test input script
# Processing 919/2124
# Ready the test input script
# Processing 920/2124
# Ready the test input script
# Processing 921/2124
# Ready the test input script
# Processing 922/2124
# Ready the test input script
# Processing 923/2124
# Ready the test input script
# Processing 924/2124
# Ready the test input script
# Processing 925/2124
# Ready the test input script
# Processing 926/2124
# Ready the test input script
# Processing 927/2124
# Ready the test input script
# Processing 928/2124
# Ready the test input script
# Processing 929/2124
# Ready the test input script
# Processing 930/2124
# Ready the test input script
# Processing 931/2124
# Ready the test input script
# Processing 932/2124
# Ready the test input script
# Processing 933/2124
# Ready the test input script
# Processing 934/2124
# Ready the test input script
# Processing 935/2124
# Ready the test input script
# Processing 936/2124
# Ready the test input script
# Processing 937/2124
# Ready the test input script
# Processing 938/2124
# Ready the test input script
# Processing 939/2124
# Ready the test input script
# Processing 940/2124
# Ready the test input script
# Processing 941/2124
# Ready the test input script
# Processing 942/2124
# Ready the test input script
# Processing 943/2124
# Ready the test input script
# Processing 944/2124
# Ready the test input script
# Processing 945/2124
# Ready the test input script
# Processing 946/2124
# Ready the test input script
# Processing 947/2124
# Ready the test input script
# Processing 948/2124
# Ready the test input script
# Processing 949/2124
# Ready the test input script
# Processing 950/2124
# Ready the test input script
# Processing 951/2124
# Ready the test input script
# Processing 952/2124
# Ready the test input script
# Processing 953/2124
# Ready the test input script
# Processing 954/2124
# Ready the test input script
# Processing 955/2124
# Ready the test input script
# Processing 956/2124
# Ready the test input script
# Processing 957/2124
# Ready the test input script
# Processing 958/2124
# Ready the test input script
# Processing 959/2124
# Ready the test input script
# Processing 960/2124
# Ready the test input script
# Processing 961/2124
# Ready the test input script
# Processing 962/2124
# Ready the test input script
# Processing 963/2124
# Ready the test input script
# Processing 964/2124
# Ready the test input script
# Processing 965/2124
# Ready the test input script
# Processing 966/2124
# Ready the test input script
# Processing 967/2124
# Ready the test input script
# Processing 968/2124
# Ready the test input script
# Processing 969/2124
# Ready the test input script
# Processing 970/2124
# Ready the test input script
# Processing 971/2124
# Ready the test input script
# Processing 972/2124
# Ready the test input script
# Processing 973/2124
# Ready the test input script
# Processing 974/2124
# Ready the test input script
# Processing 975/2124
# Ready the test input script
# Processing 976/2124
# Ready the test input script
# Processing 977/2124
# Ready the test input script
# Processing 978/2124
# Ready the test input script
# Processing 979/2124
# Ready the test input script
# Processing 980/2124
# Ready the test input script
# Processing 981/2124
# Ready the test input script
# Processing 982/2124
# Ready the test input script
# Processing 983/2124
# Ready the test input script
# Processing 984/2124
# Ready the test input script
# Processing 985/2124
# Ready the test input script
# Processing 986/2124
# Ready the test input script
# Processing 987/2124
# Ready the test input script
# Processing 988/2124
# Ready the test input script
# Processing 989/2124
# Ready the test input script
# Processing 990/2124
# Ready the test input script
# Processing 991/2124
# Ready the test input script
# Processing 992/2124
# Ready the test input script
# Processing 993/2124
# Ready the test input script
# Processing 994/2124
# Ready the test input script
# Processing 995/2124
# Ready the test input script
# Processing 996/2124
# Ready the test input script
# Processing 997/2124
# Ready the test input script
# Processing 998/2124
# Ready the test input script
# Processing 999/2124
# Ready the test input script
# Processing 1000/2124
# Ready the test input script
# Processing 1001/2124
# Ready the test input script
# Processing 1002/2124
# Ready the test input script
# ...
# Ready the test input script
# Processing 1802/2124
# Ready the test input script
# Processing 1803/2124
# Ready the test input script
# Processing 1804/2124
# Ready the test input script
# Processing 1805/2124
# Ready the test input script
# Processing 1806/2124
# Ready the test input script
# Processing 1807/2124
# Ready the test input script
# Processing 1808/2124
# Ready the test input script
# Processing 1809/2124
# Ready the test input script
# Processing 1810/2124
# Ready the test input script
# Processing 1811/2124
# Ready the test input script
# Processing 1812/2124
# Ready the test input script
# Processing 1813/2124
# Ready the test input script
# Processing 1814/2124
# Ready the test input script
# Processing 1815/2124
# Ready the test input script
# Processing 1816/2124
# Ready the test input script
# Processing 1817/2124
# Ready the test input script
# Processing 1818/2124
# Ready the test input script
# Processing 1819/2124
# Ready the test input script
# Processing 1820/2124
# Ready the test input script
# Processing 1821/2124
# Ready the test input script
# Processing 1822/2124
# Ready the test input script
# Processing 1823/2124
# Ready the test input script
# Processing 1824/2124
# Ready the test input script
# Processing 1825/2124
# Ready the test input script
# Processing 1826/2124
# Ready the test input script
# Processing 1827/2124
# Ready the test input script
# Processing 1828/2124
# Ready the test input script
# Processing 1829/2124
# Ready the test input script
# Processing 1830/2124
# Ready the test input script
# Processing 1831/2124
# Ready the test input script
# Processing 1832/2124
# Ready the test input script
# Processing 1833/2124
# Ready the test input script
# Processing 1834/2124
# Ready the test input script
# Processing 1835/2124
# Ready the test input script
# Processing 1836/2124
# Ready the test input script
# Processing 1837/2124
# Ready the test input script
# Processing 1838/2124
# Ready the test input script
# Processing 1839/2124
# Ready the test input script
# Processing 1840/2124
# Ready the test input script
# Processing 1841/2124
# Ready the test input script
# Processing 1842/2124
# Ready the test input script
# Processing 1843/2124
# Ready the test input script
# Processing 1844/2124
# Ready the test input script
# Processing 1845/2124
# Ready the test input script
# Processing 1846/2124
# Ready the test input script
# Processing 1847/2124
# Ready the test input script
# Processing 1848/2124
# Ready the test input script
# Processing 1849/2124
# Ready the test input script
# Processing 1850/2124
# Ready the test input script
# Processing 1851/2124
# Ready the test input script
# Processing 1852/2124
# Ready the test input script
# Processing 1853/2124
# Ready the test input script
# Processing 1854/2124
# Ready the test input script
# Processing 1855/2124
# Ready the test input script
# Processing 1856/2124
# Ready the test input script
# Processing 1857/2124
# Ready the test input script
# Processing 1858/2124
# Ready the test input script
# Processing 1859/2124
# Ready the test input script
# Processing 1860/2124
# Ready the test input script
# Processing 1861/2124
# Ready the test input script
# Processing 1862/2124
# Ready the test input script
# Processing 1863/2124
# Ready the test input script
# Processing 1864/2124
# Ready the test input script
# Processing 1865/2124
# Ready the test input script
# Processing 1866/2124
# Ready the test input script
# Processing 1867/2124
# Ready the test input script
# Processing 1868/2124
# Ready the test input script
# Processing 1869/2124
# Ready the test input script
# Processing 1870/2124
# Ready the test input script
# Processing 1871/2124
# Ready the test input script
# Processing 1872/2124
# Ready the test input script
# Processing 1873/2124
# Ready the test input script
# Processing 1874/2124
# Ready the test input script
# Processing 1875/2124
# Ready the test input script
# Processing 1876/2124
# Ready the test input script
# Processing 1877/2124
# Ready the test input script
# Processing 1878/2124
# Ready the test input script
# Processing 1879/2124
# Ready the test input script
# Processing 1880/2124
# Ready the test input script
# Processing 1881/2124
# Ready the test input script
# Processing 1882/2124
# Ready the test input script
# Processing 1883/2124
# Ready the test input script
# Processing 1884/2124
# Ready the test input script
# Processing 1885/2124
# Ready the test input script
# Processing 1886/2124
# Ready the test input script
# Processing 1887/2124
# Ready the test input script
# Processing 1888/2124
# Ready the test input script
# Processing 1889/2124
# Ready the test input script
# Processing 1890/2124
# Ready the test input script
# Processing 1891/2124
# Ready the test input script
# Processing 1892/2124
# Ready the test input script
# Processing 1893/2124
# Ready the test input script
# Processing 1894/2124
# Ready the test input script
# Processing 1895/2124
# Ready the test input script
# Processing 1896/2124
# Ready the test input script
# Processing 1897/2124
# Ready the test input script
# Processing 1898/2124
# Ready the test input script
# Processing 1899/2124
# Ready the test input script
# Processing 1900/2124
# Ready the test input script
# Processing 1901/2124
# Ready the test input script
# Processing 1902/2124
# Ready the test input script
# Processing 1903/2124
# Ready the test input script
# Processing 1904/2124
# Ready the test input script
# Processing 1905/2124
# Ready the test input script
# Processing 1906/2124
# Ready the test input script
# Processing 1907/2124
# Ready the test input script
# Processing 1908/2124
# Ready the test input script
# Processing 1909/2124
# Ready the test input script
# Processing 1910/2124
# Ready the test input script
# Processing 1911/2124
# Ready the test input script
# Processing 1912/2124
# Ready the test input script
# Processing 1913/2124
# Ready the test input script
# Processing 1914/2124
# Ready the test input script
# Processing 1915/2124
# Ready the test input script
# Processing 1916/2124
# Ready the test input script
# Processing 1917/2124
# Ready the test input script
# Processing 1918/2124
# Ready the test input script
# Processing 1919/2124
# Ready the test input script
# Processing 1920/2124
# Ready the test input script
# Processing 1921/2124
# Ready the test input script
# Processing 1922/2124
# Ready the test input script
# Processing 1923/2124
# Ready the test input script
# Processing 1924/2124
# Ready the test input script
# Processing 1925/2124
# Ready the test input script
# Processing 1926/2124
# Ready the test input script
# Processing 1927/2124
# Ready the test input script
# Processing 1928/2124
# Ready the test input script
# Processing 1929/2124
# Ready the test input script
# Processing 1930/2124
# Ready the test input script
# Processing 1931/2124
# Ready the test input script
# Processing 1932/2124
# Ready the test input script
# Processing 1933/2124
# Ready the test input script
# Processing 1934/2124
# Ready the test input script
# Processing 1935/2124
# Ready the test input script
# Processing 1936/2124
# Ready the test input script
# Processing 1937/2124
# Ready the test input script
# Processing 1938/2124
# Ready the test input script
# Processing 1939/2124
# Ready the test input script
# Processing 1940/2124
# Ready the test input script
# Processing 1941/2124
# Ready the test input script
# Processing 1942/2124
# Ready the test input script
# Processing 1943/2124
# Ready the test input script
# Processing 1944/2124
# Ready the test input script
# Processing 1945/2124
# Ready the test input script
# Processing 1946/2124
# Ready the test input script
# Processing 1947/2124
# Ready the test input script
# Processing 1948/2124
# Ready the test input script
# Processing 1949/2124
# Ready the test input script
# Processing 1950/2124
# Ready the test input script
# Processing 1951/2124
# Ready the test input script
# Processing 1952/2124
# Ready the test input script
# Processing 1953/2124
# Ready the test input script
# Processing 1954/2124
# Ready the test input script
# Processing 1955/2124
# Ready the test input script
# Processing 1956/2124
# Ready the test input script
# Processing 1957/2124
# Ready the test input script
# Processing 1958/2124
# Ready the test input script
# Processing 1959/2124
# Ready the test input script
# Processing 1960/2124
# Ready the test input script
# Processing 1961/2124
# Ready the test input script
# Processing 1962/2124
# Ready the test input script
# Processing 1963/2124
# Ready the test input script
# Processing 1964/2124
# Ready the test input script
# Processing 1965/2124
# Ready the test input script
# Processing 1966/2124
# Ready the test input script
# Processing 1967/2124
# Ready the test input script
# Processing 1968/2124
# Ready the test input script
# Processing 1969/2124
# Ready the test input script
# Processing 1970/2124
# Ready the test input script
# Processing 1971/2124
# Ready the test input script
# Processing 1972/2124
# Ready the test input script
# Processing 1973/2124
# Ready the test input script
# Processing 1974/2124
# Ready the test input script
# Processing 1975/2124
# Ready the test input script
# Processing 1976/2124
# Ready the test input script
# Processing 1977/2124
# Ready the test input script
# Processing 1978/2124
# Ready the test input script
# Processing 1979/2124
# Ready the test input script
# Processing 1980/2124
# Ready the test input script
# Processing 1981/2124
# Ready the test input script
# Processing 1982/2124
# Ready the test input script
# Processing 1983/2124
# Ready the test input script
# Processing 1984/2124
# Ready the test input script
# Processing 1985/2124
# Ready the test input script
# Processing 1986/2124
# Ready the test input script
# Processing 1987/2124
# Ready the test input script
# Processing 1988/2124
# Ready the test input script
# Processing 1989/2124
# Ready the test input script
# Processing 1990/2124
# Ready the test input script
# Processing 1991/2124
# Ready the test input script
# Processing 1992/2124
# Ready the test input script
# Processing 1993/2124
# Ready the test input script
# Processing 1994/2124
# Ready the test input script
# Processing 1995/2124
# Ready the test input script
# Processing 1996/2124
# Ready the test input script
# Processing 1997/2124
# Ready the test input script
# Processing 1998/2124
# Ready the test input script
# Processing 1999/2124
# Ready the test input script
# Processing 2000/2124
# Ready the test input script
# Processing 2001/2124
# Ready the test input script
# Processing 2002/2124
# Ready the test input script
# Processing 2003/2124
# Ready the test input script
# Processing 2004/2124
# Ready the test input script
# Processing 2005/2124
# Ready the test input script
# Processing 2006/2124
# Ready the test input script
# Processing 2007/2124
# Ready the test input script
# Processing 2008/2124
# Ready the test input script
# Processing 2009/2124
# Ready the test input script
# Processing 2010/2124
# Ready the test input script
# Processing 2011/2124
# Ready the test input script
# Processing 2012/2124
# Ready the test input script
# Processing 2013/2124
# Ready the test input script
# Processing 2014/2124
# Ready the test input script
# Processing 2015/2124
# Ready the test input script
# Processing 2016/2124
# Ready the test input script
# Processing 2017/2124
# Ready the test input script
# Processing 2018/2124
# Ready the test input script
# Processing 2019/2124
# Ready the test input script
# Processing 2020/2124
# Ready the test input script
# Processing 2021/2124
# Ready the test input script
# Processing 2022/2124
# Ready the test input script
# Processing 2023/2124
# Ready the test input script
# Processing 2024/2124
# Ready the test input script
# Processing 2025/2124
# Ready the test input script
# Processing 2026/2124
# Ready the test input script
# Processing 2027/2124
# Ready the test input script
# Processing 2028/2124
# Ready the test input script
# Processing 2029/2124
# Ready the test input script
# Processing 2030/2124
# Ready the test input script
# Processing 2031/2124
# Ready the test input script
# Processing 2032/2124
# Ready the test input script
# Processing 2033/2124
# Ready the test input script
# Processing 2034/2124
# Ready the test input script
# Processing 2035/2124
# Ready the test input script
# Processing 2036/2124
# Ready the test input script
# Processing 2037/2124
# Ready the test input script
# Processing 2038/2124
# Ready the test input script
# Processing 2039/2124
# Ready the test input script
# Processing 2040/2124
# Ready the test input script
# Processing 2041/2124
# Ready the test input script
# Processing 2042/2124
# Ready the test input script
# Processing 2043/2124
# Ready the test input script
# Processing 2044/2124
# Ready the test input script
# Processing 2045/2124
# Ready the test input script
# Processing 2046/2124
# Ready the test input script
# Processing 2047/2124
# Ready the test input script
# Processing 2048/2124
# Ready the test input script
# Processing 2049/2124
# Ready the test input script
# Processing 2050/2124
# Ready the test input script
# Processing 2051/2124
# Ready the test input script
# Processing 2052/2124
# Ready the test input script
# Processing 2053/2124
# Ready the test input script
# Processing 2054/2124
# Ready the test input script
# Processing 2055/2124
# Ready the test input script
# Processing 2056/2124
# Ready the test input script
# Processing 2057/2124
# Ready the test input script
# Processing 2058/2124
# Ready the test input script
# Processing 2059/2124
# Ready the test input script
# Processing 2060/2124
# Ready the test input script
# Processing 2061/2124
# Ready the test input script
# Processing 2062/2124
# Ready the test input script
# Processing 2063/2124
# Ready the test input script
# Processing 2064/2124
# Ready the test input script
# Processing 2065/2124
# Ready the test input script
# Processing 2066/2124
# Ready the test input script
# Processing 2067/2124
# Ready the test input script
# Processing 2068/2124
# Ready the test input script
# Processing 2069/2124
# Ready the test input script
# Processing 2070/2124
# Ready the test input script
# Processing 2071/2124
# Ready the test input script
# Processing 2072/2124
# Ready the test input script
# Processing 2073/2124
# Ready the test input script
# Processing 2074/2124
# Ready the test input script
# Processing 2075/2124
# Ready the test input script
# Processing 2076/2124
# Ready the test input script
# Processing 2077/2124
# Ready the test input script
# Processing 2078/2124
# Ready the test input script
# Processing 2079/2124
# Ready the test input script
# Processing 2080/2124
# Ready the test input script
# Processing 2081/2124
# Ready the test input script
# Processing 2082/2124
# Ready the test input script
# Processing 2083/2124
# Ready the test input script
# Processing 2084/2124
# Ready the test input script
# Processing 2085/2124
# Ready the test input script
# Processing 2086/2124
# Ready the test input script
# Processing 2087/2124
# Ready the test input script
# Processing 2088/2124
# Ready the test input script
# Processing 2089/2124
# Ready the test input script
# Processing 2090/2124
# Ready the test input script
# Processing 2091/2124
# Ready the test input script
# Processing 2092/2124
# Ready the test input script
# Processing 2093/2124
# Ready the test input script
# Processing 2094/2124
# Ready the test input script
# Processing 2095/2124
# Ready the test input script
# Processing 2096/2124
# Ready the test input script
# Processing 2097/2124
# Ready the test input script
# Processing 2098/2124
# Ready the test input script
# Processing 2099/2124
# Ready the test input script
# Processing 2100/2124
# Ready the test input script
# Processing 2101/2124
# Ready the test input script
# Processing 2102/2124
# Ready the test input script
# Processing 2103/2124
# Ready the test input script
# Processing 2104/2124
# Ready the test input script
# Processing 2105/2124
# Ready the test input script
# Processing 2106/2124
# Ready the test input script
# Processing 2107/2124
# Ready the test input script
# Processing 2108/2124
# Ready the test input script
# Processing 2109/2124
# Ready the test input script
# Processing 2110/2124
# Ready the test input script
# Processing 2111/2124
# Ready the test input script
# Processing 2112/2124
# Ready the test input script
# Processing 2113/2124
# Ready the test input script
# Processing 2114/2124
# Ready the test input script
# Processing 2115/2124
# Ready the test input script
# Processing 2116/2124
# Ready the test input script
# Processing 2117/2124
# Ready the test input script
# Processing 2118/2124
# Ready the test input script
# Processing 2119/2124
# Ready the test input script
# Processing 2120/2124
# Ready the test input script
# Processing 2121/2124
# Ready the test input script
# Processing 2122/2124
# Ready the test input script
# Processing 2123/2124
# Ready the test input script
# Processing 2124/2124
# Ready the test input script
# ASR+Text2Pickup accuracy: 98.44632768361582%
# STT error contribution rate: 60.60606060606061%
# STT error ignored rate: 95.88477366255144%

# %%
# Plot error distance

import matplotlib.pyplot as plt

plt.plot(error)

# %%
# Evaluate model inference time

times = np.asarray(times)
STT_compute_times = np.load('/content/drive/MyDrive/Speech2Pickup/ASR_deepspeech2_STT_time_evaluate.npz')['times']
taken_times_final = times + STT_compute_times

Q1 = np.percentile(taken_times_final, 25)
Q2 = np.percentile(taken_times_final, 50)
Q3 = np.percentile(taken_times_final, 75)
std = np.std(taken_times_final)
print('Q1: {}, Q2: {}, Q3: {}, std: {}'.format(Q1, Q2, Q3, std))
# Out:
# Q1: 0.5419020056724548, Q2: 0.6013569831848145, Q3: 0.6704972982406616, std: 0.08869463024173282

# %%
# Evaluate model inference error (distance)

print('mean: {}, std: {}'.format(np.mean(distances), np.std(distances)))
# Out:
# mean: 5.997649950561786, std: 8.75930729987981

# %%
# Evaluate model inference error (error)

print('mean: {}, std: {}'.format(np.mean(error), np.std(error)))
# Out:
# mean: 67.37079806069426, std: 27.972818931387415
